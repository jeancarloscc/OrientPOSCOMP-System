# %% [markdown]
# # Transformações dos Dados

# %%
# %run ../services/imports.py
# %run ../services/visualization.py

# %%
visualizacao = Visualizacao()

# %%
# dataset = pd.read_csv('../dados/dataset_poscomp.csv')

# %%
dataset = pd.read_csv('../dados/poscomp_frame.csv')

# %%
dataset
# Out:
#                                nome             cpf sexo estado  \
# 0              ABELARDO VIEIRA MOTA  013.692.163-94    M     CE
# 1     ABNER MATHEUS COSTA DE ARAUJO  111.403.224-78    M     RS
# 2     ABNER MOISES DOS SANTOS GOMES  388.006.478-47    M     SP
# 3           ABRAAO DA COSTA SANTANA  908.770.632-49    M     PA
# 4        ADA RAQUEL DOS SANTOS CRUZ  027.031.892-57    F     AM
# ...                             ...             ...  ...    ...
# 9245     YSABELLE PINHEIRO DE SOUSA  441.733.968-64    F     SP
# 9246       YULLI DIAS TAVARES ALVES  088.898.286-09    F     MG
# 9247            YURE PEREIRA CAMPOS  747.477.624-34    M     PB
# 9248           YURI MORASKI BATISTA  140.092.867-25    M     ES
# 9249                 YURI SILVA VAZ  025.435.730-03    M     RS
#
#           inscricao                          especialidade presente dia1  \
# 0     39401645886-1                           Demais áreas             S
# 1     39401663587-8  metodologias e técnicas de computação             S
# 2     39401651770-6                 engenharia de software             S
# 3     39401671273-0                 sistemas de informação             S
# 4     39401684751-5                     computação gráfica             S
# ...             ...                                    ...           ...
# 9245  51801390716-5                       ciência de dados             S
# 9246  51801394883-5                inteligência artificial             S
# 9247  51801395371-7                  redes de computadores             S
# 9248  51801396055-5                inteligência artificial             S
# 9249  51801354647-6                    sistemas embarcados             S
#
#                    cargo  matemática discreta  cálculo diferencial e integral  \
# 0     Mestrado/Doutorado                  3.0                             3.0
# 1     Mestrado/Doutorado                  3.0                             2.0
# 2     Mestrado/Doutorado                  0.0                             1.0
# 3     Mestrado/Doutorado                  1.0                             0.0
# 4     Mestrado/Doutorado                  0.0                             0.0
# ...                  ...                  ...                             ...
# 9245  Mestrado/Doutorado                  2.0                             1.0
# 9246  Mestrado/Doutorado                  3.0                             2.0
# 9247  Mestrado/Doutorado                  1.0                             1.0
# 9248  Mestrado/Doutorado                  1.0                             2.0
# 9249  Mestrado/Doutorado                  3.0                             2.0
#
#       ...  banco de dados   ano  idade    regiao  matematica  fund_computacao  \
# 0     ...             1.0  2016     27  nordeste        14.0             21.0
# 1     ...             1.0  2016     21       sul        16.0             22.0
# 2     ...             1.0  2016     25   sudeste         4.0             16.0
# 3     ...             0.0  2016     30     norte         4.0             13.0
# 4     ...             1.0  2016     19     norte         6.0             15.0
# ...   ...             ...   ...    ...       ...         ...              ...
# 9245  ...             2.0  2019     24   sudeste         7.0              9.0
# 9246  ...             1.0  2019     22   sudeste        14.0             16.0
# 9247  ...             1.0  2019     48  nordeste        10.0             16.0
# 9248  ...             0.0  2019     25   sudeste        10.0             16.0
# 9249  ...             0.0  2019     24       sul        13.0             17.0
#
#       tec_computacao  total         linhas_pesquisas  area_concentration
# 0               10.0   45.0                   Outros         informatica
# 1               12.0   50.0   engenharia de software         informatica
# 2                8.0   28.0   engenharia de software         informatica
# 3                7.0   24.0   sistemas de computação          computacao
# 4               11.0   32.0                   Outros         informatica
# ...              ...    ...                      ...                 ...
# 9245             6.0   22.0  inteligência artificial          computacao
# 9246             8.0   38.0  inteligência artificial          computacao
# 9247             9.0   35.0    redes de computadores         informatica
# 9248             6.0   32.0  inteligência artificial          computacao
# 9249             5.0   35.0    redes de computadores         informatica
#
# [9250 rows x 42 columns]

# %% [markdown]
# ## Adicionar os eixos e somar de cada candidato

# %%
# visualizacao.plot_top_especialidades_por_sexo(dados_poscomp, 'M', top_n=10, save_path='imagens/espec_masculino.eps')
# visualizacao.plot_top_especialidades_por_sexo(dados_poscomp, 'F', top_n=10, save_path='imagens/espec_feminino.eps')

# %%
dados_poscomp = dataset.copy()

# %%
def plot_histogram(dataset, columns):
    for column in columns:
        sns.histplot(dataset[column], kde=True)
        plt.xlabel(f'Média de {column}')
        plt.ylabel('Frequência')
        plt.title(f'Distribuição das médias de {column}')
        plt.show()

columns = ['matematica', 'fund_computacao', 'tec_computacao']
plot_histogram(dados_poscomp, columns)

# %%
media = dados_poscomp['total'].mean()
desvio_padrao = dados_poscomp['total'].std()
variancia = dados_poscomp['total'].var()

# %%
print(f'Média: {media}, Desvio Padrão: {desvio_padrao}, Variância: {variancia}')
# Out:
# Média: 30.02983783783784, Desvio Padrão: 7.549023581134008, Variância: 56.98775702851732

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Probabilidade desejada
probabilidade = 0.95

# Encontre os valores de X correspondentes ao intervalo de probabilidade
limite_inferior, limite_superior = norm.interval(probabilidade, loc=media, scale=desvio_padrao)

# Valores para o gráfico
x = np.linspace(media - 3 * desvio_padrao, media + 3 * desvio_padrao, 1000)
pdf = norm.pdf(x, loc=media, scale=desvio_padrao)

# Plote o gráfico da PDF
plt.plot(x, pdf, label='PDF')
plt.fill_between(x, pdf, where=(x >= limite_inferior) & (x <= limite_superior), alpha=0.5, label=f'Área de {probabilidade*100}%')
plt.xlabel('Valores de X')
plt.ylabel('PDF')
plt.title(f'Distribuição Normal ({media}, {desvio_padrao})')

# Exiba o gráfico
plt.legend()
plt.grid(True)
plt.show()

# Exiba o intervalo de valores de X correspondentes à probabilidade
print(f'Intervalo de {probabilidade*100}% de probabilidade: [{limite_inferior:.2f}, {limite_superior:.2f}]')
# Out:
# Intervalo de 95.0% de probabilidade: [15.23, 44.83]

# %%
sns.boxplot(y=dados_poscomp["total"]);

# %% [markdown]
# #### Técnica para eliminar os outlier

# %%
df = dados_poscomp.copy()

# %%
def check_outlier(value, quantiles, amplitude):
    if (value < quantiles[0] - (1 * amplitude)) or (value > quantiles[2] + (1 * amplitude)):
        return True
    return False

# %%
# quartis das quantidades de caracteres dos títulos
import statistics

quantiles_nota = statistics.quantiles(df["total"])
print("Quartis de nota total:", quantiles_nota)
amplitude_nota = quantiles_nota[2] - quantiles_nota[0]
print("Amplitude interquartil de nota:", amplitude_nota)

quantiles_mat = statistics.quantiles(df["matematica"])
print("Quartis de nota matematica:", quantiles_mat)
amplitude_mat = quantiles_mat[2] - quantiles_mat[0]
print("Amplitude interquartil de nota:", amplitude_mat)

quantiles_fund = statistics.quantiles(df["fund_computacao"])
print("Quartis de nota Fundamento da Computação:", quantiles_fund)
amplitude_fund = quantiles_fund[2] - quantiles_fund[0]
print("Amplitude interquartil de nota:", amplitude_fund)

quantiles_tec = statistics.quantiles(df["tec_computacao"])
print("Quartis de nota Tecnologia da Computação:", quantiles_tec)
amplitude_tec = quantiles_tec[2] - quantiles_tec[0]
print("Amplitude interquartil de nota:", amplitude_tec)
# Out:
# Quartis de nota total: [25.0, 30.0, 35.0]
# Amplitude interquartil de nota: 10.0
# Quartis de nota matematica: [6.0, 8.0, 10.0]
# Amplitude interquartil de nota: 4.0
# Quartis de nota Fundamento da Computação: [11.0, 14.0, 17.0]
# Amplitude interquartil de nota: 6.0
# Quartis de nota Tecnologia da Computação: [6.0, 8.0, 10.0]
# Amplitude interquartil de nota: 4.0

# %%
# determinação dos outliers nos títulos
df["outlier_nota"] = df["total"].map(lambda x: check_outlier(
    value=x,
    quantiles=quantiles_nota,
    amplitude=amplitude_nota
))
df["outlier_mat"] = df["matematica"].map(lambda x: check_outlier(
    value=x,
    quantiles=quantiles_mat,
    amplitude=amplitude_mat
))
df["outlier_fund"] = df["fund_computacao"].map(lambda x: check_outlier(
    value=x,
    quantiles=quantiles_fund,
    amplitude=amplitude_fund
))
df["outlier_tec"] = df["tec_computacao"].map(lambda x: check_outlier(
    value=x,
    quantiles=quantiles_tec,
    amplitude=amplitude_tec
))

# %%
df.outlier_fund.value_counts()
# Out:
# outlier_fund
# False    9152
# True       98
# Name: count, dtype: int64

# %%
df.outlier_tec.value_counts()
# Out:
# outlier_tec
# False    9153
# True       97
# Name: count, dtype: int64

# %%
df.outlier_mat.value_counts()
# Out:
# outlier_mat
# False    8847
# True      403
# Name: count, dtype: int64

# %%
df.outlier_nota.value_counts()
# Out:
# outlier_nota
# False    8916
# True      334
# Name: count, dtype: int64

# %%
sns.boxplot(y=df["total"]);

# %%
df = df.loc[~((df["outlier_nota"]) | (df['outlier_fund']) | (df['outlier_mat']) | (df['outlier_tec']))]
df = df.iloc[:,:-4]
df.shape
# Out:
# (8601, 42)

# %%
dados_poscomp.describe().T
# Out:
#                                                   count         mean  \
# matemática discreta                              9250.0     1.217405
# cálculo diferencial e integral                   9250.0     1.129946
# álgebra linear                                   9250.0     1.346486
# geometria analítica                              9250.0     1.022486
# análise combinatória                             9250.0     1.214054
# probabilidade e estatística                      9250.0     0.830486
# lógica matemática                                9250.0     1.336649
# organização de arquivos e dados                  9250.0     0.759243
# técnicas de programação                          9250.0     2.225946
# circuitos digitais                               9250.0     1.286703
# análise de algoritmos                            9250.0     1.698703
# teoria dos grafos                                9250.0     1.461405
# linguagens formais, autômatos e computabilidade  9250.0     1.050378
# algoritmos e estruturas de dados                 9250.0     1.628432
# linguagens de programação                        9250.0     2.036649
# sistemas operacionais                            9250.0     1.008865
# arquitetura e organização de computadores        9250.0     0.918811
# redes de computadores                            9250.0     1.193622
# computação gráfica                               9250.0     0.495784
# inteligência artificial                          9250.0     1.137838
# engenharia de software                           9250.0     1.066162
# sistemas distribuídos                            9250.0     1.788324
# compiladores                                     9250.0     0.557081
# processamento de imagens                         9250.0     0.724757
# banco de dados                                   9250.0     0.893622
# ano                                              9250.0  2017.213514
# idade                                            9250.0    26.357297
# matematica                                       9250.0     8.097514
# fund_computacao                                  9250.0    14.075135
# tec_computacao                                   9250.0     7.857189
# total                                            9250.0    30.029838
#
#                                                       std     min     25%  \
# matemática discreta                              0.831832     0.0     1.0
# cálculo diferencial e integral                   0.830662     0.0     1.0
# álgebra linear                                   0.970453     0.0     1.0
# geometria analítica                              0.893467     0.0     0.0
# análise combinatória                             0.889273     0.0     1.0
# probabilidade e estatística                      0.700787     0.0     0.0
# lógica matemática                                0.872303     0.0     1.0
# organização de arquivos e dados                  0.760897     0.0     0.0
# técnicas de programação                          0.699982     0.0     2.0
# circuitos digitais                               0.843312     0.0     1.0
# análise de algoritmos                            1.012800     0.0     1.0
# teoria dos grafos                                0.977348     0.0     1.0
# linguagens formais, autômatos e computabilidade  0.897283     0.0     0.0
# algoritmos e estruturas de dados                 0.958988     0.0     1.0
# linguagens de programação                        0.819047     0.0     2.0
# sistemas operacionais                            0.801075     0.0     0.0
# arquitetura e organização de computadores        0.785452     0.0     0.0
# redes de computadores                            0.828604     0.0     1.0
# computação gráfica                               0.602221     0.0     0.0
# inteligência artificial                          0.748463     0.0     1.0
# engenharia de software                           0.887894     0.0     0.0
# sistemas distribuídos                            0.901071     0.0     1.0
# compiladores                                     0.629436     0.0     0.0
# processamento de imagens                         0.670593     0.0     0.0
# banco de dados                                   0.776821     0.0     0.0
# ano                                              1.091416  2016.0  2016.0
# idade                                            5.802048    18.0    22.0
# matematica                                       3.198822     0.0     6.0
# fund_computacao                                  3.784536     0.0    11.0
# tec_computacao                                   2.616356     0.0     6.0
# total                                            7.549024     1.0    25.0
#
#                                                     50%     75%     max
# matemática discreta                                 1.0     2.0     3.0
# cálculo diferencial e integral                      1.0     2.0     3.0
# álgebra linear                                      1.0     2.0     3.0
# geometria analítica                                 1.0     2.0     3.0
# análise combinatória                                1.0     2.0     3.0
# probabilidade e estatística                         1.0     1.0     2.0
# lógica matemática                                   1.0     2.0     3.0
# organização de arquivos e dados                     1.0     1.0     3.0
# técnicas de programação                             2.0     3.0     3.0
# circuitos digitais                                  1.0     2.0     3.0
# análise de algoritmos                               2.0     3.0     3.0
# teoria dos grafos                                   1.0     2.0     3.0
# linguagens formais, autômatos e computabilidade     1.0     2.0     3.0
# algoritmos e estruturas de dados                    2.0     2.0     3.0
# linguagens de programação                           2.0     3.0     3.0
# sistemas operacionais                               1.0     1.0     3.0
# arquitetura e organização de computadores           1.0     1.0     3.0
# redes de computadores                               1.0     2.0     3.0
# computação gráfica                                  0.0     1.0     2.0
# inteligência artificial                             1.0     2.0     2.0
# engenharia de software                              1.0     2.0     3.0
# sistemas distribuídos                               2.0     2.0     3.0
# compiladores                                        0.0     1.0     2.0
# processamento de imagens                            1.0     1.0     2.0
# banco de dados                                      1.0     1.0     3.0
# ano                                              2017.0  2018.0  2019.0
# idade                                              24.0    29.0    67.0
# matematica                                          8.0    10.0    20.0
# fund_computacao                                    14.0    17.0    28.0
# tec_computacao                                      8.0    10.0    18.0
# total                                              30.0    35.0    62.0

# %%
df.shape
# Out:
# (8601, 42)

# %%
# print(f'Perda - {(374 / 9849) * 100:.2f}% dos dados') # informação importante

# %%
# Pegar apenas os candidatos com nota final acima de 17 pontos.
nova_dados_poscomp = dados_poscomp[dados_poscomp['total'] >=1]

# %%
nova_dados_poscomp.columns
# Out:
# Index(['nome', 'cpf', 'sexo', 'estado', 'inscricao', 'especialidade',
#        'presente dia1', 'cargo', 'matemática discreta',
#        'cálculo diferencial e integral', 'álgebra linear',
#        'geometria analítica', 'análise combinatória',
#        'probabilidade e estatística', 'lógica matemática',
#        'organização de arquivos e dados', 'técnicas de programação',
#        'circuitos digitais', 'análise de algoritmos', 'teoria dos grafos',
#        'linguagens formais, autômatos e computabilidade',
#        'algoritmos e estruturas de dados', 'linguagens de programação',
#        'sistemas operacionais', 'arquitetura e organização de computadores',
#        'redes de computadores', 'computação gráfica',
#        'inteligência artificial', 'engenharia de software',
#        'sistemas distribuídos', 'compiladores', 'processamento de imagens',
#        'banco de dados', 'ano', 'idade', 'regiao', 'matematica',
#        'fund_computacao', 'tec_computacao', 'total', 'linhas_pesquisas',
#        'area_concentration'],
#       dtype='object')

# %%
nova_dados_poscomp = nova_dados_poscomp.drop(['nome','presente dia1','cargo', 'ano', 'cpf'], axis=1)

# %%
df = df.drop(['nome','presente dia1','cargo', 'ano'], axis=1)

# %% [markdown]
# ###### Transformar os tipos de dados

# %%
list_disc = ['matemática discreta',
       'cálculo diferencial e integral', 'álgebra linear',
       'geometria analítica', 'análise combinatória',
       'probabilidade e estatística', 'lógica matemática',
       'organização de arquivos e dados', 'técnicas de programação',
       'circuitos digitais', 'análise de algoritmos', 'teoria dos grafos',
       'linguagens formais, autômatos e computabilidade',
       'algoritmos e estruturas de dados', 'linguagens de programação',
       'sistemas operacionais', 'arquitetura e organização de computadores',
       'redes de computadores', 'computação gráfica',
       'inteligência artificial', 'engenharia de software',
       'sistemas distribuídos', 'compiladores', 'processamento de imagens',
       'banco de dados','matematica', 'fund_computacao',
       'tec_computacao', 'total']

# %%
list_categorico = ['sexo', 'estado', 'especialidade','linhas_pesquisas', 'area_concentration',
       'regiao',]

# %%
df[list_disc] = df[list_disc].astype(int)
df[list_categorico] = df[list_categorico].astype('category')

# %%
nova_dados_poscomp[list_disc] = nova_dados_poscomp[list_disc].astype(int)
nova_dados_poscomp[list_categorico] = nova_dados_poscomp[list_categorico].astype('category')

# %%
# nova_dados_poscomp = nova_dados_poscomp[(nova_dados_poscomp['linhas_pesquisas'] != 'Demais areas') & (nova_dados_poscomp['linhas_pesquisas'] != 'Outros')]

# %%
df = df[(df['linhas_pesquisas'] != 'Demais areas') & (df['linhas_pesquisas'] != 'Outros')]

# %%
# nova_dados_poscomp.to_csv('../dados/df_poscomp.csv', index=False)

# %%
# df.to_csv('../dados/df_poscompTest.csv', index=False)

# %% [markdown]
# ## Verificar o comportamento dos candidatos de acordo com a linha de pesquisa

# %%
nova_dados_poscomp.head()
# Out:
#   sexo estado      inscricao                          especialidade  \
# 0    M     CE  39401645886-1                           Demais áreas
# 1    M     RS  39401663587-8  metodologias e técnicas de computação
# 2    M     SP  39401651770-6                 engenharia de software
# 3    M     PA  39401671273-0                 sistemas de informação
# 4    F     AM  39401684751-5                     computação gráfica
#
#    matemática discreta  cálculo diferencial e integral  álgebra linear  \
# 0                    3                               3               2
# 1                    3                               2               3
# 2                    0                               1               1
# 3                    1                               0               1
# 4                    0                               0               2
#
#    geometria analítica  análise combinatória  probabilidade e estatística  \
# 0                    0                     1                            2
# 1                    2                     2                            2
# 2                    1                     0                            0
# 3                    1                     0                            0
# 4                    2                     1                            0
#
#    ...  processamento de imagens  banco de dados  idade    regiao  matematica  \
# 0  ...                         1               1     27  nordeste          14
# 1  ...                         2               1     21       sul          16
# 2  ...                         2               1     25   sudeste           4
# 3  ...                         1               0     30     norte           4
# 4  ...                         1               1     19     norte           6
#
#    fund_computacao  tec_computacao  total        linhas_pesquisas  \
# 0               21              10     45                  Outros
# 1               22              12     50  engenharia de software
# 2               16               8     28  engenharia de software
# 3               13               7     24  sistemas de computação
# 4               15              11     32                  Outros
#
#    area_concentration
# 0         informatica
# 1         informatica
# 2         informatica
# 3          computacao
# 4         informatica
#
# [5 rows x 37 columns]

# %%
nova_dados_poscomp['area_concentration'].value_counts()
# Out:
# area_concentration
# computacao     4708
# informatica    4542
# Name: count, dtype: int64

# %%
nova_dados_poscomp['linhas_pesquisas'].value_counts()
# Out:
# linhas_pesquisas
# inteligência artificial    2755
# sistemas de computação     1953
# Outros                     1832
# engenharia de software     1737
# redes de computadores       973
# Name: count, dtype: int64

# %%
# plt.figure(figsize=(20, 15))
# plot = sns.lmplot(x="total", y="total", data=dados_poscomp, fit_reg=False, hue='linhas_pesquisas', legend=False)

# # Move the legend to an empty part of the plot
# plt.legend(loc='lower right')
# plt.show()
