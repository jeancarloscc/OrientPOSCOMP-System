# %%
# %run services/imports.py

# %%
dataset_poscomp = pd.read_csv('dados/df_poscomp.csv')

# %% [markdown]
# ## Medidas de posição e dispersão

# %%
dataset_poscomp.head(3)
# Out:
#   SEXO ESTADO                          ESPECIALIDADE  Matemática Discreta  \
# 0    M     RS  metodologias e técnicas de computação                  3.0
# 1    M     SP                 engenharia de software                  0.0
# 2    M     PA                 sistemas de informação                  1.0
#
#    Cálculo Diferencial e Integral  Álgebra Linear  Geometria Analítica  \
# 0                             2.0             3.0                  2.0
# 1                             1.0             1.0                  1.0
# 2                             0.0             1.0                  1.0
#
#    Análise Combinatória  Probabilidade e Estatística  Lógica Matemática  ...  \
# 0                   2.0                          2.0                2.0  ...
# 1                   0.0                          0.0                1.0  ...
# 2                   0.0                          0.0                1.0  ...
#
#    Processamento de Imagens  Banco de Dados  IDADE  matematica  \
# 0                       2.0             1.0     21        16.0
# 1                       2.0             1.0     25         4.0
# 2                       1.0             0.0     30         4.0
#
#    fund_computacao  tec_computacao  total        linhas_pesquisas  \
# 0             22.0            12.0   50.0  engenharia de software
# 1             16.0             8.0   28.0  engenharia de software
# 2             13.0             7.0   24.0  sistemas de computação
#
#    area_concentration   REGIAO
# 0         informatica      sul
# 1         informatica  sudeste
# 2          computacao    norte
#
# [3 rows x 36 columns]

# %%
dataset_poscomp.describe().T
# Out:
#                                                   count       mean       std  \
# Matemática Discreta                              9998.0   1.223345  0.824155
# Cálculo Diferencial e Integral                   9998.0   1.094519  0.825453
# Álgebra Linear                                   9998.0   1.285857  0.969528
# Geometria Analítica                              9998.0   1.020604  0.897227
# Análise Combinatória                             9998.0   1.192539  0.889086
# Probabilidade e Estatística                      9998.0   0.826565  0.691860
# Lógica Matemática                                9998.0   1.320364  0.879272
# Organização de Arquivos e Dados                  9998.0   0.763953  0.759122
# Técnicas de Programação                          9998.0   2.191338  0.717671
# Circuitos Digitais                               9998.0   1.244949  0.854711
# Análise de Algoritmos                            9998.0   1.689638  1.028159
# Teoria dos Grafos                                9998.0   1.443189  0.968713
# Linguagens Formais, Autômatos e Computabilidade  9998.0   0.973295  0.881828
# Algoritmos e Estruturas de Dados                 9998.0   1.642028  0.959509
# Linguagens de Programação                        9998.0   2.055111  0.817352
# Sistemas Operacionais                            9998.0   0.995599  0.799608
# Arquitetura e Organização de Computadores        9998.0   0.925785  0.784651
# Redes de Computadores                            9998.0   1.202240  0.824810
# Computação Gráfica                               9998.0   0.506501  0.605490
# Inteligência Artificial                          9998.0   1.121324  0.749635
# Engenharia de Software                           9998.0   1.076815  0.896070
# Sistemas Distribuídos                            9998.0   1.769454  0.894762
# Compiladores                                     9998.0   0.574115  0.636694
# Processamento de Imagens                         9998.0   0.726845  0.669056
# Banco de Dados                                   9998.0   0.917584  0.775364
# IDADE                                            9998.0  26.550010  5.831539
# matematica                                       9998.0   7.963793  3.180617
# fund_computacao                                  9998.0  13.924885  3.782665
# tec_computacao                                   9998.0   7.894879  2.568780
# total                                            9998.0  29.783557  7.479034
#
#                                                  min    25%   50%   75%   max
# Matemática Discreta                              0.0   1.00   1.0   2.0   3.0
# Cálculo Diferencial e Integral                   0.0   1.00   1.0   2.0   3.0
# Álgebra Linear                                   0.0   1.00   1.0   2.0   3.0
# Geometria Analítica                              0.0   0.00   1.0   2.0   3.0
# Análise Combinatória                             0.0   1.00   1.0   2.0   3.0
# Probabilidade e Estatística                      0.0   0.00   1.0   1.0   2.0
# Lógica Matemática                                0.0   1.00   1.0   2.0   3.0
# Organização de Arquivos e Dados                  0.0   0.00   1.0   1.0   3.0
# Técnicas de Programação                          0.0   2.00   2.0   3.0   3.0
# Circuitos Digitais                               0.0   1.00   1.0   2.0   3.0
# Análise de Algoritmos                            0.0   1.00   2.0   3.0   3.0
# Teoria dos Grafos                                0.0   1.00   1.0   2.0   3.0
# Linguagens Formais, Autômatos e Computabilidade  0.0   0.00   1.0   2.0   3.0
# Algoritmos e Estruturas de Dados                 0.0   1.00   2.0   2.0   3.0
# Linguagens de Programação                        0.0   2.00   2.0   3.0   3.0
# Sistemas Operacionais                            0.0   0.00   1.0   1.0   3.0
# Arquitetura e Organização de Computadores        0.0   0.00   1.0   1.0   3.0
# Redes de Computadores                            0.0   1.00   1.0   2.0   3.0
# Computação Gráfica                               0.0   0.00   0.0   1.0   2.0
# Inteligência Artificial                          0.0   1.00   1.0   2.0   2.0
# Engenharia de Software                           0.0   0.00   1.0   2.0   3.0
# Sistemas Distribuídos                            0.0   1.00   2.0   2.0   3.0
# Compiladores                                     0.0   0.00   0.0   1.0   2.0
# Processamento de Imagens                         0.0   0.00   1.0   1.0   2.0
# Banco de Dados                                   0.0   0.00   1.0   1.0   3.0
# IDADE                                           -1.0  22.25  25.0  29.0  67.0
# matematica                                       0.0   6.00   8.0  10.0  20.0
# fund_computacao                                  2.0  11.00  14.0  16.0  28.0
# tec_computacao                                   2.0   6.00   8.0  10.0  18.0
# total                                            8.0  24.00  29.0  35.0  62.0

# %%
renda_estatisticas_por_uf = dataset_poscomp.groupby(['ESPECIALIDADE']).agg({'matematica': ['mean', 'median', 'max','min', 'std'],
                                                            'fund_computacao': ['mean', 'median', 'max','min', 'std'],
                                                            'tec_computacao': ['mean', 'median', 'max','min', 'std']})
renda_estatisticas_por_uf
# Out:
#                                       matematica                              \
#                                             mean median   max  min       std
# ESPECIALIDADE
# aplicações computacionais               8.578947    8.5  16.0  2.0  3.394151
# aprendizado de máquina                  9.048544    9.0  18.0  1.0  3.277368
# arquitetura de computadores             7.719388    7.0  16.0  1.0  3.091399
# banco de dados                          7.607623    7.0  19.0  1.0  3.006485
# ciência de dados                        8.439560    8.0  17.0  1.0  3.379198
# computação aplicada                     7.489842    7.0  17.0  1.0  2.865264
# computação gráfica                      9.072000    9.0  20.0  2.0  3.307313
# computação visual                       9.168367    9.0  20.0  1.0  3.390366
# engenharia de software                  7.103470    7.0  19.0  0.0  2.766118
# informática na educação                 6.703704    6.0  17.0  1.0  2.515843
# inteligência artificial                 8.516147    8.0  20.0  0.0  3.246219
# metodologias e técnicas de computação   7.984733    8.0  19.0  1.0  3.282333
# modelagem computacional                 7.946078    8.0  16.0  1.0  2.880550
# otimização                             10.439103   10.0  20.0  2.0  3.857111
# processamento paralelo e distribuído    7.877049    7.0  14.0  3.0  2.579570
# redes de computadores                   7.430946    7.0  18.0  1.0  2.985619
# sistemas de computação                  7.943507    7.0  20.0  1.0  3.274815
# sistemas de informação                  7.555195    7.0  19.0  1.0  3.042817
# sistemas embarcados                     8.139423    8.0  18.0  0.0  2.856433
# sistemas inteligentes                   8.155340    8.0  16.0  2.0  2.977173
# tecnologia da informação                7.559701    7.0  16.0  2.0  3.020011
# visão computacional                     8.014851    8.0  19.0  2.0  2.914158
#
#                                       fund_computacao                    \
#                                                  mean median   max  min
# ESPECIALIDADE
# aplicações computacionais                   13.815789   14.0  22.0  4.0
# aprendizado de máquina                      15.485437   16.0  26.0  6.0
# arquitetura de computadores                 13.637755   13.5  24.0  3.0
# banco de dados                              13.616592   14.0  25.0  3.0
# ciência de dados                            13.648352   13.0  24.0  4.0
# computação aplicada                         13.227991   13.0  24.0  4.0
# computação gráfica                          15.592000   15.0  28.0  5.0
# computação visual                           15.005102   15.0  25.0  5.0
# engenharia de software                      13.114622   13.0  26.0  3.0
# informática na educação                     12.148148   12.0  23.0  5.0
# inteligência artificial                     14.556103   15.0  28.0  2.0
# metodologias e técnicas de computação       14.209924   14.0  25.0  5.0
# modelagem computacional                     13.730392   14.0  24.0  5.0
# otimização                                  15.919872   16.0  27.0  4.0
# processamento paralelo e distribuído        15.385246   15.0  25.0  6.0
# redes de computadores                       13.345269   13.0  25.0  3.0
# sistemas de computação                      13.779897   14.0  25.0  3.0
# sistemas de informação                      13.347403   13.0  25.0  4.0
# sistemas embarcados                         14.572115   15.0  24.0  4.0
# sistemas inteligentes                       14.097087   14.0  24.0  4.0
# tecnologia da informação                    13.141791   13.0  23.0  6.0
# visão computacional                         14.732673   15.0  22.0  7.0
#
#                                                 tec_computacao               \
#                                             std           mean median   max
# ESPECIALIDADE
# aplicações computacionais              3.943328       8.052632    8.0  14.0
# aprendizado de máquina                 3.635675       8.592233    9.0  14.0
# arquitetura de computadores            4.047969       7.846939    8.0  14.0
# banco de dados                         3.537103       7.798206    8.0  16.0
# ciência de dados                       3.533185       8.076923    8.0  15.0
# computação aplicada                    3.789714       8.000000    8.0  15.0
# computação gráfica                     4.175767       8.832000    9.0  18.0
# computação visual                      3.625405       8.530612    9.0  16.0
# engenharia de software                 3.482290       7.346344    7.0  16.0
# informática na educação                3.386802       6.948148    7.0  12.0
# inteligência artificial                3.854344       8.176245    8.0  16.0
# metodologias e técnicas de computação  3.921380       7.656489    8.0  14.0
# modelagem computacional                3.661927       7.926471    8.0  15.0
# otimização                             4.094148       8.467949    8.0  15.0
# processamento paralelo e distribuído   3.251056       8.303279    8.0  15.0
# redes de computadores                  3.847073       7.952685    8.0  15.0
# sistemas de computação                 3.612872       7.816581    8.0  16.0
# sistemas de informação                 3.577176       7.584416    7.0  16.0
# sistemas embarcados                    4.163865       8.216346    8.0  17.0
# sistemas inteligentes                  3.576385       7.893204    8.0  14.0
# tecnologia da informação               3.703591       7.619403    8.0  13.0
# visão computacional                    3.352852       8.128713    8.0  16.0
#
#
#                                        min       std
# ESPECIALIDADE
# aplicações computacionais              3.0  2.353089
# aprendizado de máquina                 2.0  2.423251
# arquitetura de computadores            2.0  2.718793
# banco de dados                         2.0  2.635897
# ciência de dados                       3.0  2.381934
# computação aplicada                    2.0  2.445792
# computação gráfica                     2.0  3.049950
# computação visual                      2.0  2.566866
# engenharia de software                 2.0  2.517809
# informática na educação                2.0  2.462612
# inteligência artificial                2.0  2.519502
# metodologias e técnicas de computação  2.0  2.619617
# modelagem computacional                3.0  2.380025
# otimização                             2.0  2.778928
# processamento paralelo e distribuído   3.0  2.541846
# redes de computadores                  2.0  2.470116
# sistemas de computação                 2.0  2.583147
# sistemas de informação                 2.0  2.598815
# sistemas embarcados                    2.0  2.793423
# sistemas inteligentes                  3.0  2.228037
# tecnologia da informação               2.0  2.250463
# visão computacional                    2.0  2.697570

# %%
renda_estatisticas_por_uf = dataset_poscomp.groupby(['linhas_pesquisas']).agg({'matematica': ['mean', 'median', 'max','min', 'std'],
                                                            'fund_computacao': ['mean', 'median', 'max','min', 'std'],
                                                            'tec_computacao': ['mean', 'median', 'max','min', 'std']})
renda_estatisticas_por_uf
# Out:
#                         matematica                              \
#                               mean median   max  min       std
# linhas_pesquisas
# Outros                    7.702296    7.0  20.0  1.0  3.036761
# engenharia de software    7.297115    7.0  19.0  0.0  2.868648
# inteligência artificial   8.733457    8.0  20.0  0.0  3.348979
# redes de computadores     7.612410    7.0  18.0  0.0  2.931555
# sistemas de computação    7.798614    7.0  20.0  1.0  3.187617
#
#                         fund_computacao                              \
#                                    mean median   max  min       std
# linhas_pesquisas
# Outros                        13.536817   13.0  28.0  3.0  3.799036
# engenharia de software        13.312981   13.0  26.0  3.0  3.577309
# inteligência artificial       14.734385   15.0  28.0  2.0  3.816825
# redes de computadores         13.798561   14.0  25.0  3.0  3.913888
# sistemas de computação        13.615418   14.0  25.0  3.0  3.651790
#
#                         tec_computacao
#                                   mean median   max  min       std
# linhas_pesquisas
# Outros                        7.903405    8.0  18.0  2.0  2.605951
# engenharia de software        7.442308    7.0  16.0  2.0  2.523681
# inteligência artificial       8.239023    8.0  16.0  2.0  2.530619
# redes de computadores         8.040468    8.0  17.0  2.0  2.542736
# sistemas de computação        7.745777    8.0  16.0  2.0  2.581746

# %%
renda_estatisticas_por_uf = dataset_poscomp.groupby(['area_concentration']).agg({'total': ['mean', 'median', 'max', 'std','sum']})
renda_estatisticas_por_uf = renda_estatisticas_por_uf.sort_values(by=('total', 'mean'), ascending=False)
renda_estatisticas_por_uf
# Out:
#                         total
#                          mean median   max       std       sum
# area_concentration
# computacao          30.645860   30.0  62.0  7.560890  169870.0
# informatica         28.710662   28.0  58.0  7.234634  127906.0

# %%
renda_estatisticas_por_uf = dataset_poscomp.groupby(['area_concentration']).agg({'matematica': ['mean', 'median', 'max', 'std'],
                                                            'fund_computacao': ['mean', 'median', 'max', 'std'],
                                                            'tec_computacao': ['mean', 'median', 'max', 'std']})
renda_estatisticas_por_uf
# Out:
#                    matematica                        fund_computacao         \
#                          mean median   max       std            mean median
# area_concentration
# computacao           8.344038    8.0  20.0  3.314636       14.268266   14.0
# informatica          7.490685    7.0  20.0  2.937967       13.497643   13.0
#
#                                    tec_computacao
#                      max       std           mean median   max       std
# area_concentration
# computacao          28.0  3.789006       8.033556    8.0  16.0  2.563371
# informatica         28.0  3.731314       7.722334    8.0  18.0  2.565335

# %%
dataset_poscomp['ESPECIALIDADE'].unique()
# Out:
# array(['metodologias e técnicas de computação', 'engenharia de software',
#        'sistemas de informação', 'computação gráfica',
#        'sistemas de computação', 'inteligência artificial',
#        'informática na educação', 'arquitetura de computadores',
#        'visão computacional', 'redes de computadores', 'banco de dados',
#        'modelagem computacional', 'processamento paralelo e distribuído',
#        'sistemas inteligentes', 'computação aplicada',
#        'sistemas embarcados', 'computação visual', 'ciência de dados',
#        'otimização', 'aprendizado de máquina',
#        'aplicações computacionais', 'tecnologia da informação'],
#       dtype=object)
