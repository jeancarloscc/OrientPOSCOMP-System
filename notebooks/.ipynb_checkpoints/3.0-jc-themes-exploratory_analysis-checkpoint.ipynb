# %% [markdown]
# # Análise Exploratória de Dados

# %% [markdown]
# <p>Este notebook apresenta a análise exploratória dos dados do POSCOMP dos anos de 2016 a 2022. É analisado o desempenho dos participantes e estudantes em relação aos temas das áreas da computação</p>

# %% [markdown]
# ## Importar bibliotecas

# %%
# %run ../services/imports.py
# %run ../services/visualization.py

# %%
# Criar instância da classe
visualizacao = Visualizacao()

# %% [markdown]
# ## Carregar a base de dados

# %%
df_poscomp = pd.read_csv("../dados/processed/df_poscomp2016-2022.csv")

# %%
df_poscomp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13997 entries, 0 to 13996
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   idade                                           13997 non-null  object
#  1   sexo                                            13997 non-null  object
#  2   estado                                          13997 non-null  object
#  3   presença                                        13997 non-null  object
#  4   cargo                                           13997 non-null  object
#  5   especialidade                                   13997 non-null  object
#  6   algoritmos_e_estruturas_de_dados                11366 non-null  float64
#  7   analise_combinatoria                            11366 non-null  float64
#  8   analise_de_algoritmos                           11366 non-null  float64
#  9   arquitetura_e_organizacao_de_computadores       11366 non-null  float64
#  10  banco_de_dados                                  11366 non-null  float64
#  11  calculo_diferencial_e_integral                  11366 non-null  float64
#  12  circuitos_digitais                              11366 non-null  float64
#  13  compiladores                                    11366 non-null  float64
#  14  computacao_grafica                              11366 non-null  float64
#  15  engenharia_de_software                          11366 non-null  float64
#  16  geometria_analitica                             11366 non-null  float64
#  17  inteligencia_artificial                         11366 non-null  float64
#  18  linguagens_de_programacao                       11366 non-null  float64
#  19  linguagens_formais_automatos_e_computabilidade  11366 non-null  float64
#  20  logica_matematica                               11366 non-null  float64
#  21  matematica_discreta                             11366 non-null  float64
#  22  organizacao_de_arquivos_e_dados                 11366 non-null  float64
#  23  probabilidade_e_estatistica                     11366 non-null  float64
#  24  processamento_de_imagens                        11366 non-null  float64
#  25  redes_de_computadores                           11366 non-null  float64
#  26  sistemas_distribuidos                           11366 non-null  float64
#  27  sistemas_operacionais                           11366 non-null  float64
#  28  teoria_dos_grafos                               11366 non-null  float64
#  29  tecnicas_de_programacao                         11366 non-null  float64
#  30  algebra_linear                                  11366 non-null  float64
#  31  ano                                             13997 non-null  int64
#  32  matematica                                      13997 non-null  float64
#  33  fund_computacao                                 13997 non-null  float64
#  34  tec_computacao                                  13997 non-null  float64
# dtypes: float64(28), int64(1), object(6)
# memory usage: 3.7+ MB

# %%
# converter os type das colunas
df_poscomp["ano"] = df_poscomp["ano"].astype("object")

# %%
# Primeiramente, será excluídos candidatos que realizaram o exame no Peru
df_poscomp = df_poscomp.query("estado != 'ou'")

# %% [markdown]
# ## Visualização de candidatos inscritos por sexo no decorrer dos anos.

# %%
qtd_sexo = df_poscomp.groupby(["sexo", "ano"]).size().reset_index(name="counts")
qtd_sexo["sexo"] = qtd_sexo["sexo"].replace({"feminino": "Feminino", "masculino": "Masculino"})

# %%
visualizacao.barplot_view(
    qtd_sexo,
    x="ano",
    y="counts",
    hue="sexo",
    fontsize=16,
    xlabel="Ano",
    ylabel="Quantidade",
    figsize=(12, 7),
    title_legend="Gênero",
    # save_path="../imagens/qtd_candidatosAno.png",
)

# %% [markdown]
# ## Agrupamento das especializadades

# %%
df_poscomp.head()
# Out:
#         idade       sexo estado presença               cargo  \
# 0  1989-11-29  masculino     ce        s  mestrado/doutorado
# 1  1995-02-23  masculino     rs        s  mestrado/doutorado
# 2  1991-12-13  masculino     sp        s  mestrado/doutorado
# 3  1986-09-29  masculino     pa        s  mestrado/doutorado
# 4  1997-12-26   feminino     am        s  mestrado/doutorado
#
#                            especialidade  algoritmos_e_estruturas_de_dados  \
# 0                   teoria da computação                               1.0
# 1  metodologias e técnicas de computação                               3.0
# 2                 engenharia de software                               1.0
# 3                 sistemas de informação                               2.0
# 4                     computação gráfica                               2.0
#
#    analise_combinatoria  analise_de_algoritmos  \
# 0                   1.0                    1.0
# 1                   2.0                    2.0
# 2                   0.0                    2.0
# 3                   0.0                    1.0
# 4                   1.0                    1.0
#
#    arquitetura_e_organizacao_de_computadores  ...  redes_de_computadores  \
# 0                                        1.0  ...                    1.0
# 1                                        1.0  ...                    2.0
# 2                                        1.0  ...                    1.0
# 3                                        0.0  ...                    2.0
# 4                                        0.0  ...                    1.0
#
#    sistemas_distribuidos  sistemas_operacionais  teoria_dos_grafos  \
# 0                    2.0                    2.0                3.0
# 1                    3.0                    2.0                3.0
# 2                    2.0                    2.0                2.0
# 3                    1.0                    0.0                2.0
# 4                    3.0                    2.0                2.0
#
#    tecnicas_de_programacao  algebra_linear   ano  matematica  fund_computacao  \
# 0                      3.0             2.0  2016        14.0             21.0
# 1                      3.0             3.0  2016        16.0             22.0
# 2                      3.0             1.0  2016         4.0             16.0
# 3                      3.0             1.0  2016         4.0             13.0
# 4                      3.0             2.0  2016         6.0             15.0
#
#    tec_computacao
# 0            10.0
# 1            12.0
# 2             8.0
# 3             7.0
# 4            11.0
#
# [5 rows x 35 columns]

# %%
qtd_especialidades = df_poscomp.groupby(["sexo","especialidade"])['matematica'].mean().sort_index(ascending=False)
qtd_especialidades
# Out:
# sexo       especialidade
# masculino  visão computacional                      6.814371
#            teoria da computação                     8.854305
#            tecnologia da informação                 6.290323
#            sistemas inteligentes                    6.860870
#            sistemas embarcados                      6.574661
#            sistemas e tecnologias da computação     6.933333
#            sistemas de informação                   6.216772
#            sistemas de computação                   6.139608
#            robótica                                 7.535211
#            redes de computadores                    6.071651
#            processamento paralelo e distribuído     6.546154
#            otimização                               8.388406
#            modelagem computacional                  6.898990
#            metodologias e técnicas de computação    6.487365
#            linguagens de programação                7.610000
#            interação humano-computador              4.975000
#            inteligência artificial                  7.041222
#            informática na educação                  5.306452
#            engenharia de software                   5.800979
#            computação visual                        6.595745
#            computação gráfica                       7.948148
#            computação aplicada                      6.419014
#            ciência de dados                         7.532787
#            bioinformática                           7.142857
#            banco de dados                           6.179724
#            arquitetura de computadores              7.428571
#            aprendizado de máquina                   7.474777
#            aplicações computacionais                7.270341
#            Demais áreas                             6.712121
# feminino   visão computacional                      6.757576
#            teoria da computação                     6.535714
#            tecnologia da informação                 5.682927
#            sistemas inteligentes                    6.150943
#            sistemas embarcados                      6.142857
#            sistemas e tecnologias da computação     7.875000
#            sistemas de informação                   5.972973
#            sistemas de computação                   5.688372
#            robótica                                 5.315789
#            redes de computadores                    6.015038
#            processamento paralelo e distribuído     6.875000
#            otimização                               8.140845
#            modelagem computacional                  6.666667
#            metodologias e técnicas de computação    5.241379
#            linguagens de programação                7.250000
#            interação humano-computador              6.250000
#            inteligência artificial                  7.008671
#            informática na educação                  5.868421
#            engenharia de software                   5.390716
#            computação visual                        7.066667
#            computação gráfica                       7.617647
#            computação aplicada                      6.317757
#            ciência de dados                         6.428571
#            bioinformática                           6.315789
#            banco de dados                           6.014706
#            arquitetura de computadores              6.625000
#            aprendizado de máquina                   7.535714
#            aplicações computacionais                7.000000
#            Demais áreas                             6.690141
# Name: matematica, dtype: float64

# %%
df = df_poscomp.loc[:, ['especialidade','matematica', 'fund_computacao', 'tec_computacao']]
qtd_especialidades = df.groupby(['especialidade']).agg("mean")
qtd_especialidades
# Out:
#                                        matematica  fund_computacao  \
# especialidade
# Demais áreas                             6.708779        11.387580
# aplicações computacionais                7.235160        12.041096
# aprendizado de máquina                   7.483461        12.659033
# arquitetura de computadores              7.338028        11.704225
# banco de dados                           6.140351        10.963158
# bioinformática                           7.000000        12.436364
# ciência de dados                         7.326667        11.713333
# computação aplicada                      6.402963        11.303704
# computação gráfica                       7.881657        13.585799
# computação visual                        6.660550        11.522936
# engenharia de software                   5.710951        10.505093
# informática na educação                  5.438272         9.833333
# inteligência artificial                  7.036545        12.002907
# interação humano-computador              5.400000        11.400000
# linguagens de programação                7.560345        12.689655
# metodologias e técnicas de computação    6.271642        11.152239
# modelagem computacional                  6.853659        11.609756
# otimização                               8.346154        12.456731
# processamento paralelo e distribuído     6.582192        12.856164
# redes de computadores                    6.064781        10.889599
# robótica                                 7.066667        11.200000
# sistemas de computação                   6.074497        10.716779
# sistemas de informação                   6.170513        10.871795
# sistemas e tecnologias da computação     7.044118        11.352941
# sistemas embarcados                      6.526104        11.570281
# sistemas inteligentes                    6.727915        11.614841
# tecnologia da informação                 6.139394        10.672727
# teoria da computação                     8.491620        13.318436
# visão computacional                      6.805000        12.030000
#
#                                        tec_computacao
# especialidade
# Demais áreas                                 6.400428
# aplicações computacionais                    6.769406
# aprendizado de máquina                       6.969466
# arquitetura de computadores                  6.563380
# banco de dados                               6.228070
# bioinformática                               6.727273
# ciência de dados                             6.540000
# computação aplicada                          6.648889
# computação gráfica                           7.733728
# computação visual                            6.477064
# engenharia de software                       5.837436
# informática na educação                      5.598765
# inteligência artificial                      6.686462
# interação humano-computador                  6.050000
# linguagens de programação                    6.974138
# metodologias e técnicas de computação        5.988060
# modelagem computacional                      6.621951
# otimização                                   6.548077
# processamento paralelo e distribuído         6.938356
# redes de computadores                        6.354927
# robótica                                     6.444444
# sistemas de computação                       6.118121
# sistemas de informação                       6.112821
# sistemas e tecnologias da computação         6.132353
# sistemas embarcados                          6.481928
# sistemas inteligentes                        6.448763
# tecnologia da informação                     6.187879
# teoria da computação                         6.782123
# visão computacional                          6.715000

# %%
qtd_especialidades.sum()
# Out:
# matematica         196.487982
# fund_computacao    338.060505
# tec_computacao     188.079308
# dtype: float64

# %%
df_poscomp
# Out:
#             idade       sexo estado presença               cargo  \
# 0      1989-11-29  masculino     ce        s  mestrado/doutorado
# 1      1995-02-23  masculino     rs        s  mestrado/doutorado
# 2      1991-12-13  masculino     sp        s  mestrado/doutorado
# 3      1986-09-29  masculino     pa        s  mestrado/doutorado
# 4      1997-12-26   feminino     am        s  mestrado/doutorado
# ...           ...        ...    ...      ...                 ...
# 13992  1998-06-12  masculino     ma        s  mestrado/doutorado
# 13993  1989-04-17   feminino     pr        s       autoavaliação
# 13994  2000-07-03  masculino     rj        s  mestrado/doutorado
# 13995  1990-01-25  masculino     sp        s  mestrado/doutorado
# 13996  1995-06-07   feminino     rs        n  mestrado/doutorado
#
#                                especialidade  \
# 0                       teoria da computação
# 1      metodologias e técnicas de computação
# 2                     engenharia de software
# 3                     sistemas de informação
# 4                         computação gráfica
# ...                                      ...
# 13992                inteligência artificial
# 13993                 aprendizado de máquina
# 13994                             otimização
# 13995                           Demais áreas
# 13996                  redes de computadores
#
#        algoritmos_e_estruturas_de_dados  analise_combinatoria  \
# 0                                   1.0                   1.0
# 1                                   3.0                   2.0
# 2                                   1.0                   0.0
# 3                                   2.0                   0.0
# 4                                   2.0                   1.0
# ...                                 ...                   ...
# 13992                               1.0                   0.0
# 13993                               2.0                   0.0
# 13994                               1.0                   1.0
# 13995                               1.0                   2.0
# 13996                               NaN                   NaN
#
#        analise_de_algoritmos  arquitetura_e_organizacao_de_computadores  ...  \
# 0                        1.0                                        1.0  ...
# 1                        2.0                                        1.0  ...
# 2                        2.0                                        1.0  ...
# 3                        1.0                                        0.0  ...
# 4                        1.0                                        0.0  ...
# ...                      ...                                        ...  ...
# 13992                    1.0                                        0.0  ...
# 13993                    0.0                                        2.0  ...
# 13994                    1.0                                        0.0  ...
# 13995                    0.0                                        1.0  ...
# 13996                    NaN                                        NaN  ...
#
#        redes_de_computadores  sistemas_distribuidos  sistemas_operacionais  \
# 0                        1.0                    2.0                    2.0
# 1                        2.0                    3.0                    2.0
# 2                        1.0                    2.0                    2.0
# 3                        2.0                    1.0                    0.0
# 4                        1.0                    3.0                    2.0
# ...                      ...                    ...                    ...
# 13992                    1.0                    2.0                    0.0
# 13993                    1.0                    0.0                    0.0
# 13994                    1.0                    2.0                    1.0
# 13995                    2.0                    2.0                    1.0
# 13996                    NaN                    NaN                    NaN
#
#        teoria_dos_grafos  tecnicas_de_programacao  algebra_linear   ano  \
# 0                    3.0                      3.0             2.0  2016
# 1                    3.0                      3.0             3.0  2016
# 2                    2.0                      3.0             1.0  2016
# 3                    2.0                      3.0             1.0  2016
# 4                    2.0                      3.0             2.0  2016
# ...                  ...                      ...             ...   ...
# 13992                0.0                      1.0             0.0  2022
# 13993                1.0                      2.0             1.0  2022
# 13994                0.0                      2.0             1.0  2022
# 13995                2.0                      1.0             3.0  2022
# 13996                NaN                      NaN             NaN  2022
#
#        matematica  fund_computacao  tec_computacao
# 0            14.0             21.0            10.0
# 1            16.0             22.0            12.0
# 2             4.0             16.0             8.0
# 3             4.0             13.0             7.0
# 4             6.0             15.0            11.0
# ...           ...              ...             ...
# 13992         3.0              6.0             7.0
# 13993         1.0             12.0             6.0
# 13994         8.0             11.0             7.0
# 13995        10.0             12.0            10.0
# 13996         0.0              0.0             0.0
#
# [13997 rows x 35 columns]

# %%
df = df_poscomp.query('presença != "n"')

# %%
def calcular_percentagem_acertos(dados, coluna_acertos):
    dados["%acerto_" + coluna_acertos] = (
        dados[coluna_acertos] / dados[coluna_acertos].sum()
    ) * 100


# Exemplo de uso:
# Supondo que 'teste_dados' é o seu DataFrame
calcular_percentagem_acertos(df, "matematica")
calcular_percentagem_acertos(df, "fund_computacao")
calcular_percentagem_acertos(df, "tec_computacao")
# calcular_percentagem_acertos(df, "total")

# %%
# Bases de dados filtradas com a porcentagens de acertos por eixos de cada estado
percentil_eixos = (
    df.groupby("especialidade")
    .agg(
        {
            "%acerto_matematica": "sum",
            "%acerto_fund_computacao": "sum",
            "%acerto_tec_computacao": "sum",
            # "%acerto_total": "sum",
        }
    )
    .reset_index()
)

# %%
# Bases de dados filtradas com a porcentagens de acertos por eixos de cada sexo
percentil_sexo = (
    df.groupby("sexo")
    .agg(
        {
            "%acerto_matematica": "sum",
            "%acerto_fund_computacao": "sum",
            "%acerto_tec_computacao": "sum",
            # "%acerto_total": "sum",
        }
    )
    .reset_index()
)

# %%
# Bases de dados filtradas com a porcentagens de acertos por eixos de cada região
percentil_estado = (
    df.groupby("estado")
    .agg(
        {
            "%acerto_matematica": "sum",
            "%acerto_fund_computacao": "sum",
            "%acerto_tec_computacao": "sum",
            # "%acerto_total": "sum",
        }
    )
    .reset_index()
)

# %%
percentil_eixos.columns
# Out:
# Index(['especialidade', '%acerto_matematica', '%acerto_fund_computacao',
#        '%acerto_tec_computacao'],
#       dtype='object')

# %%
percentil_eixos = percentil_eixos.round(
    {"%acerto_matematica": 2, "%acerto_fund_computacao": 2, "%acerto_tec_computacao": 2}
)

percentil_estado = percentil_estado.round(
    {"%acerto_matematica": 2, "%acerto_fund_computacao": 2, "%acerto_tec_computacao": 2}
)

# %%
percentil_eixos
# Out:
#                             especialidade  %acerto_matematica  \
# 0                            Demais áreas                3.43
# 1               aplicações computacionais                3.47
# 2                  aprendizado de máquina                3.22
# 3             arquitetura de computadores                0.57
# 4                          banco de dados                3.84
# 5                          bioinformática                0.84
# 6                        ciência de dados                1.20
# 7                     computação aplicada                4.74
# 8                      computação gráfica                1.46
# 9                       computação visual                0.80
# 10                 engenharia de software               14.74
# 11                informática na educação                0.97
# 12                inteligência artificial               18.57
# 13            interação humano-computador                0.36
# 14              linguagens de programação                0.96
# 15  metodologias e técnicas de computação                2.30
# 16                modelagem computacional                1.85
# 17                             otimização                3.80
# 18   processamento paralelo e distribuído                1.05
# 19                  redes de computadores                7.28
# 20                               robótica                0.70
# 21                 sistemas de computação                9.92
# 22                 sistemas de informação                5.27
# 23   sistemas e tecnologias da computação                0.52
# 24                    sistemas embarcados                1.78
# 25                  sistemas inteligentes                2.09
# 26               tecnologia da informação                1.11
# 27                   teoria da computação                1.67
# 28                    visão computacional                1.49
#
#     %acerto_fund_computacao  %acerto_tec_computacao
# 0                      3.35                    3.35
# 1                      3.32                    3.33
# 2                      3.13                    3.07
# 3                      0.52                    0.52
# 4                      3.93                    3.98
# 5                      0.86                    0.83
# 6                      1.11                    1.10
# 7                      4.80                    5.04
# 8                      1.45                    1.47
# 9                      0.79                    0.79
# 10                    15.58                   15.44
# 11                     1.00                    1.02
# 12                    18.19                   18.07
# 13                     0.43                    0.41
# 14                     0.93                    0.91
# 15                     2.35                    2.25
# 16                     1.80                    1.83
# 17                     3.26                    3.06
# 18                     1.18                    1.14
# 19                     7.51                    7.82
# 20                     0.63                    0.65
# 21                    10.05                   10.23
# 22                     5.34                    5.35
# 23                     0.49                    0.47
# 24                     1.81                    1.81
# 25                     2.07                    2.05
# 26                     1.11                    1.15
# 27                     1.50                    1.36
# 28                     1.51                    1.51

# %%
percentil_sexo
# Out:
#         sexo  %acerto_matematica  %acerto_fund_computacao  \
# 0   feminino           16.111677                15.826143
# 1  masculino           83.888323                84.173857
#
#    %acerto_tec_computacao
# 0               15.764487
# 1               84.235513

# %%
percentil_estado
# Out:
#    estado  %acerto_matematica  %acerto_fund_computacao  %acerto_tec_computacao
# 0      ac                0.04                     0.04                    0.03
# 1      al                1.46                     1.43                    1.48
# 2      am                0.56                     0.61                    0.62
# 3      ap                0.08                     0.08                    0.11
# 4      ba                1.05                     1.16                    1.14
# 5      ce                5.78                     5.61                    5.65
# 6      df                0.78                     0.74                    0.74
# 7      es                3.49                     3.34                    3.33
# 8      go                3.60                     3.84                    3.80
# 9      ma                2.68                     2.74                    2.89
# 10     mg               13.01                    12.90                   12.51
# 11     ms                3.88                     3.98                    3.76
# 12     mt                1.11                     1.17                    1.17
# 13     pa                4.11                     4.26                    4.51
# 14     pb                5.28                     5.57                    5.50
# 15     pe                0.49                     0.45                    0.42
# 16     pi                2.67                     2.88                    3.03
# 17     pr                7.76                     8.11                    8.14
# 18     rj                3.78                     3.34                    3.27
# 19     rn                1.47                     1.45                    1.43
# 20     ro                0.13                     0.12                    0.13
# 21     rr                0.03                     0.03                    0.04
# 22     rs                9.24                     9.45                    9.58
# 23     sc                5.21                     5.35                    5.53
# 24     se                0.96                     0.97                    0.98
# 25     sp               20.97                    19.98                   19.80
# 26     to                0.38                     0.41                    0.42
