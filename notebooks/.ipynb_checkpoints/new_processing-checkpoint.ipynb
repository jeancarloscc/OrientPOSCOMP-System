# %% [markdown]
# # Importação das bibliotecas

# %%
# %run ../services/imports.py
# %run ../services/visualization.py

# %run ../services/function.py
# %run ../services/classifier_evaluation.py

# %%
# Criar instância da classe
visualizacao = Visualizacao()

# %%
dataset_poscomp = pd.read_csv("../dados/processed/df_poscomp2016-2022.csv")

# %%
dataset_poscomp
# Out:
#             idade       sexo estado presença               cargo  \
# 0      1992-10-27  masculino     ou        s  mestrado/doutorado
# 1      1989-11-29  masculino     ce        s  mestrado/doutorado
# 2      1995-02-23  masculino     rs        s  mestrado/doutorado
# 3      1991-12-13  masculino     sp        s  mestrado/doutorado
# 4      1986-09-29  masculino     pa        s  mestrado/doutorado
# ...           ...        ...    ...      ...                 ...
# 15104  1998-06-12  masculino     ma        s  mestrado/doutorado
# 15105  1989-04-17   feminino     pr        s       autoavaliação
# 15106  2000-07-03  masculino     rj        s  mestrado/doutorado
# 15107  1990-01-25  masculino     sp        s  mestrado/doutorado
# 15108  1995-06-07   feminino     rs        n  mestrado/doutorado
#
#                                            especialidade  \
# 0                                inteligência artificial
# 1                                   teoria da computação
# 2                   metodologia e técnicas da computação
# 3                                 engenharia de software
# 4         modelagem e gerência de sistemas de informação
# ...                                                  ...
# 15104  logica, inteligencia artificial e metodos formais
# 15105                             aprendizado de maquina
# 15106  algoritimos, otimizacao combinatoria, e teoria...
# 15107                          linguagens de programacao
# 15108      redes de computadores e sistemas distribuidos
#
#        algoritmos_e_estruturas_de_dados  analise_combinatoria  \
# 0                                   3.0                   2.0
# 1                                   1.0                   1.0
# 2                                   3.0                   2.0
# 3                                   1.0                   0.0
# 4                                   2.0                   0.0
# ...                                 ...                   ...
# 15104                               1.0                   0.0
# 15105                               2.0                   0.0
# 15106                               1.0                   1.0
# 15107                               1.0                   2.0
# 15108                               NaN                   NaN
#
#        analise_de_algoritmos  arquitetura_e_organizacao_de_computadores  ...  \
# 0                        3.0                                        1.0  ...
# 1                        1.0                                        1.0  ...
# 2                        2.0                                        1.0  ...
# 3                        2.0                                        1.0  ...
# 4                        1.0                                        0.0  ...
# ...                      ...                                        ...  ...
# 15104                    1.0                                        0.0  ...
# 15105                    0.0                                        2.0  ...
# 15106                    1.0                                        0.0  ...
# 15107                    0.0                                        1.0  ...
# 15108                    NaN                                        NaN  ...
#
#        organizacao_de_arquivos_e_dados  probabilidade_e_estatistica  \
# 0                                  0.0                          1.0
# 1                                  2.0                          2.0
# 2                                  1.0                          2.0
# 3                                  1.0                          0.0
# 4                                  0.0                          0.0
# ...                                ...                          ...
# 15104                              0.0                          1.0
# 15105                              0.0                          0.0
# 15106                              2.0                          0.0
# 15107                              1.0                          1.0
# 15108                              NaN                          NaN
#
#        processamento_de_imagens  redes_de_computadores  sistemas_distribuidos  \
# 0                           2.0                    1.0                    3.0
# 1                           1.0                    1.0                    2.0
# 2                           2.0                    2.0                    3.0
# 3                           2.0                    1.0                    2.0
# 4                           1.0                    2.0                    1.0
# ...                         ...                    ...                    ...
# 15104                       1.0                    1.0                    2.0
# 15105                       1.0                    1.0                    0.0
# 15106                       1.0                    1.0                    2.0
# 15107                       2.0                    2.0                    2.0
# 15108                       NaN                    NaN                    NaN
#
#        sistemas_operacionais  teoria_dos_grafos  tecnicas_de_programacao  \
# 0                        0.0                2.0                      3.0
# 1                        2.0                3.0                      3.0
# 2                        2.0                3.0                      3.0
# 3                        2.0                2.0                      3.0
# 4                        0.0                2.0                      3.0
# ...                      ...                ...                      ...
# 15104                    0.0                0.0                      1.0
# 15105                    0.0                1.0                      2.0
# 15106                    1.0                0.0                      2.0
# 15107                    1.0                2.0                      1.0
# 15108                    NaN                NaN                      NaN
#
#        algebra_linear   ano
# 0                 3.0  2016
# 1                 2.0  2016
# 2                 3.0  2016
# 3                 1.0  2016
# 4                 1.0  2016
# ...               ...   ...
# 15104             0.0  2022
# 15105             1.0  2022
# 15106             1.0  2022
# 15107             3.0  2022
# 15108             NaN  2022
#
# [15109 rows x 32 columns]

# %%
# converter os type das colunas
dataset_poscomp["ano"] = dataset_poscomp["ano"].astype("object")

# %%
# Primeiramente, será excluídos candidatos que realizaram o exame no Peru
dataset_poscomp = dataset_poscomp.query("estado != 'ou'")

# %% [markdown]
# ## Estatisticas sobre candidatos dos sexo diferentes

# %%
qtd_sexo = dataset_poscomp.groupby(["sexo", "ano"]).size().reset_index(name="counts")
qtd_sexo["sexo"] = qtd_sexo["sexo"].replace({"feminino": "Feminino", "masculino": "Masculino"})

# %%
visualizacao.barplot_view(
    qtd_sexo,
    x="ano",
    y="counts",
    hue="sexo",
    fontsize=16,
    xlabel="Ano",
    ylabel="Quantidade",
    figsize=(12, 7),
    title_legend="Gênero",
    # save_path="../imagens/qtd_candidatosAno.png",
)

# %%
qtd_sexo
# Out:
#         sexo   ano  counts
# 0   Feminino  2016     683
# 1   Feminino  2017     679
# 2   Feminino  2018     565
# 3   Feminino  2019     487
# 4   Feminino  2022      78
# 5  Masculino  2016    3475
# 6  Masculino  2017    3299
# 7  Masculino  2018    2823
# 8  Masculino  2019    2333
# 9  Masculino  2022     449

# %%
qtd_ano = (
    dataset_poscomp.groupby(["presença", "ano"]).size().reset_index(name="counts")
)

# %%
qtd_ano['presença'].replace({'n':'Ausentes',
                                  's':'Presentes'}, inplace=True)

# %%
visualizacao.barplot_view(
    dataframe=qtd_ano,
    x="ano",
    y="counts",
    hue="presença",
    title_legend="Participação",
    figsize=(12, 7),
    xlabel='Ano',
    ylabel='Quantidade',
    fontsize=18,
    # save_path="../imagens/faltantes_presentes.pdf",
)

# %% [markdown]
# ## Converter as idade dos candidatos

# %%
from datetime import date

def calculate_age(row):
    birth_year = int(
        row["idade"].split("-")[0]
    )  # Extrai o ano de nascimento a partir da data de nascimento
    exam_year = row["ano"]  # Obtém o ano da realização da prova
    age = exam_year - birth_year
    return age


# Aplique a função calculate_age ao DataFrame para calcular as idades com base nos anos.
dataset_poscomp["idade"] = dataset_poscomp.apply(calculate_age, axis=1)

# %%
dataset_poscomp
# Out:
#        idade       sexo estado presença               cargo  \
# 1         27  masculino     ce        s  mestrado/doutorado
# 2         21  masculino     rs        s  mestrado/doutorado
# 3         25  masculino     sp        s  mestrado/doutorado
# 4         30  masculino     pa        s  mestrado/doutorado
# 5         25  masculino     mt        s       autoavaliação
# ...      ...        ...    ...      ...                 ...
# 15104     24  masculino     ma        s  mestrado/doutorado
# 15105     33   feminino     pr        s       autoavaliação
# 15106     22  masculino     rj        s  mestrado/doutorado
# 15107     32  masculino     sp        s  mestrado/doutorado
# 15108     27   feminino     rs        n  mestrado/doutorado
#
#                                            especialidade  \
# 1                                   teoria da computação
# 2                   metodologia e técnicas da computação
# 3                                 engenharia de software
# 4         modelagem e gerência de sistemas de informação
# 5                                                    NaN
# ...                                                  ...
# 15104  logica, inteligencia artificial e metodos formais
# 15105                             aprendizado de maquina
# 15106  algoritimos, otimizacao combinatoria, e teoria...
# 15107                          linguagens de programacao
# 15108      redes de computadores e sistemas distribuidos
#
#        algoritmos_e_estruturas_de_dados  analise_combinatoria  \
# 1                                   1.0                   1.0
# 2                                   3.0                   2.0
# 3                                   1.0                   0.0
# 4                                   2.0                   0.0
# 5                                   0.0                   3.0
# ...                                 ...                   ...
# 15104                               1.0                   0.0
# 15105                               2.0                   0.0
# 15106                               1.0                   1.0
# 15107                               1.0                   2.0
# 15108                               NaN                   NaN
#
#        analise_de_algoritmos  arquitetura_e_organizacao_de_computadores  ...  \
# 1                        1.0                                        1.0  ...
# 2                        2.0                                        1.0  ...
# 3                        2.0                                        1.0  ...
# 4                        1.0                                        0.0  ...
# 5                        1.0                                        0.0  ...
# ...                      ...                                        ...  ...
# 15104                    1.0                                        0.0  ...
# 15105                    0.0                                        2.0  ...
# 15106                    1.0                                        0.0  ...
# 15107                    0.0                                        1.0  ...
# 15108                    NaN                                        NaN  ...
#
#        organizacao_de_arquivos_e_dados  probabilidade_e_estatistica  \
# 1                                  2.0                          2.0
# 2                                  1.0                          2.0
# 3                                  1.0                          0.0
# 4                                  0.0                          0.0
# 5                                  0.0                          0.0
# ...                                ...                          ...
# 15104                              0.0                          1.0
# 15105                              0.0                          0.0
# 15106                              2.0                          0.0
# 15107                              1.0                          1.0
# 15108                              NaN                          NaN
#
#        processamento_de_imagens  redes_de_computadores  sistemas_distribuidos  \
# 1                           1.0                    1.0                    2.0
# 2                           2.0                    2.0                    3.0
# 3                           2.0                    1.0                    2.0
# 4                           1.0                    2.0                    1.0
# 5                           1.0                    1.0                    2.0
# ...                         ...                    ...                    ...
# 15104                       1.0                    1.0                    2.0
# 15105                       1.0                    1.0                    0.0
# 15106                       1.0                    1.0                    2.0
# 15107                       2.0                    2.0                    2.0
# 15108                       NaN                    NaN                    NaN
#
#        sistemas_operacionais  teoria_dos_grafos  tecnicas_de_programacao  \
# 1                        2.0                3.0                      3.0
# 2                        2.0                3.0                      3.0
# 3                        2.0                2.0                      3.0
# 4                        0.0                2.0                      3.0
# 5                        2.0                1.0                      2.0
# ...                      ...                ...                      ...
# 15104                    0.0                0.0                      1.0
# 15105                    0.0                1.0                      2.0
# 15106                    1.0                0.0                      2.0
# 15107                    1.0                2.0                      1.0
# 15108                    NaN                NaN                      NaN
#
#        algebra_linear   ano
# 1                 2.0  2016
# 2                 3.0  2016
# 3                 1.0  2016
# 4                 1.0  2016
# 5                 2.0  2016
# ...               ...   ...
# 15104             0.0  2022
# 15105             1.0  2022
# 15106             1.0  2022
# 15107             3.0  2022
# 15108             NaN  2022
#
# [14871 rows x 32 columns]

# %%
dataset_poscomp["idade"].min()
# Out:
# -1

# %%
dataset_poscomp = dataset_poscomp[dataset_poscomp["idade"] >= 18]

# %%
dataset_poscomp["idade"].value_counts(bins=7, sort=False)
# Out:
# (17.95, 25.0]    7972
# (25.0, 32.0]     4446
# (32.0, 39.0]     1706
# (39.0, 46.0]      529
# (46.0, 53.0]      174
# (53.0, 60.0]       36
# (60.0, 67.0]        6
# Name: count, dtype: int64

# %%
dataset_poscomp.duplicated().sum()
# Out:
# 231

# %% [markdown]
# ## Verificação dos valores faltantes

# %%
colunas_categoricas = [
    # "nome",
    # "cpf",
    "sexo",
    "estado",
    "especialidade",
    "presença",
    "cargo",
]

for coluna in colunas_categoricas:
    tem_interrigacao = dataset_poscomp[coluna].isna().any()
    if tem_interrigacao:
        print(f"Na coluna ' {coluna} existem valores 'NaN'")
# Out:
# Na coluna ' especialidade existem valores 'NaN'

# %%
for coluna in colunas_categoricas:
    dataset_poscomp[coluna] = dataset_poscomp[coluna].replace(" ?", np.nan)

# %% [markdown]
# ## Ánalises de pessoas inscritas no POSCOMP no decorrer dos anos

# %%
# Aqui estou adicionando as regiões dos estados brasileiros
for i in lesr.regioes_brasil_siglas:
    dataset_poscomp.loc[
        dataset_poscomp["estado"].isin(lesr.regioes_brasil_siglas[i]), "regiao"
    ] = i
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # Aqui estou adicionando as regiões dos estados brasileiros
# ----> 2 for i in lesr.regioes_brasil_siglas:
#       3     dataset_poscomp.loc[
#       4         dataset_poscomp["estado"].isin(lesr.regioes_brasil_siglas[i]), "regiao"
#       5     ] = i
#
# NameError: name 'lesr' is not defined

# %%
qtd_registered_year = dataset_poscomp.drop_duplicates(
    subset="cpf", keep="first", ignore_index=True
)

# %%
qtd_region = qtd_registered_year.groupby(["regiao"]).size().reset_index(name="counts")

# %%
region_percent = qtd_region["counts"].to_numpy()
region_percent = 100 * region_percent / region_percent.sum()
region_percent = np.around(region_percent, 2)

# %%
qtd_region["Porcentagem regiao"] = region_percent
# qtd_region.style.format({'Porcentagem regiao':'{:.2f}%'})

# %%
region_brazil = {
    "centro_oeste": "Centro-Oeste",
    "nordeste": "Nordeste",
    "norte": "Norte",
    "sudeste": "Sudeste",
    "sul": "Sul",
}

# %%
qtd_region["regiao"] = qtd_region["regiao"].replace(region_brazil)

# %%
qtd_region

# %%
qtd_region.sort_values(by='counts', ascending=False, inplace=True)

# %%
def func(pct, allvals):
    absolute = int(np.round(pct / 100.0 * np.sum(allvals)))
    return f"{pct:.2f}%\n({absolute:d})"


fig, ax = plt.subplots(figsize=(15, 8), subplot_kw=dict(aspect="equal"))

# Usar as informações do DataFrame
wedges, texts, autotexts = ax.pie(
    qtd_region["counts"],
    autopct=lambda pct: func(pct, qtd_region["counts"]),
    textprops=dict(color="w"),
)

ax.legend(
    wedges,
    qtd_region["regiao"],
    title="Região",
    loc="center left",
    bbox_to_anchor=(1, 0, 0.5, 1),
    fontsize="x-large",
    title_fontsize="x-large",
)

plt.setp(autotexts, size=20, weight="bold")
plt.tight_layout()
plt.savefig("../imagens/pie.pdf", bbox_inches="tight", dpi=600, transparent=True)
plt.show()

# %%
qtd_regiao_estado = (
    qtd_registered_year.groupby(["regiao", "estado"]).size().reset_index(name="counts")
)
qtd_regiao_estado["regiao"] = qtd_regiao_estado["regiao"].replace(region_brazil)

# %%
visualizacao.barplot_view(
    qtd_regiao_estado.sort_values(["counts"], ascending=False),
    x="estado",
    y="counts",
    hue="regiao",
    figsize=(18, 7),
    dodge=False,
    title_legend="Região",
    save_path="../imagens/qtd_região.pdf",
    fontsize=25
)

# %%
qtd_region_gender = (
    qtd_registered_year.groupby(["regiao", "sexo"]).size().reset_index(name="counts")
)

# %%
qtd_region_gender["regiao"] = qtd_region_gender["regiao"].replace(region_brazil)
qtd_region_gender["sexo"] = qtd_region_gender["sexo"].replace(
    {"F": "Feminino", "M": "Masculino"}
)

# %%
qtd_region_gender

# %%
region_gender_percent = qtd_region_gender["counts"].to_numpy()
region_gender_percent = 100 * region_gender_percent / region_gender_percent.sum()
region_gender_percent = np.around(region_gender_percent, 2)

# %%
qtd_region_gender["Porcentagem regiao"] = region_gender_percent
qtd_region_gender.style.format({"Porcentagem regiao": "{:.2f}%"})

# %%
qtd_region_gender.info()

# %%
visualizacao.barplot_view_procents(
    qtd_region_gender.sort_values(["counts"], ascending=True),
    x="regiao",
    y="Porcentagem regiao",
    hue="sexo",
    xlabel="Região",
    title_legend="Sexo",
    figsize=(10, 7),
    save_path="../imagens/qtd_região.png",
)

# %% [markdown]
# ## Adicionar os eixos e somar de cada candidato

# %%
dataset_poscomp["matematica"] = dataset_poscomp.loc[
    :,
    [
        "matemática discreta",
        "cálculo diferencial e integral",
        "álgebra linear",
        "geometria analítica",
        "análise combinatória",
        "probabilidade e estatística",
        "lógica matemática",
    ],
].sum(axis=1)

# %%
dataset_poscomp["fund_computacao"] = dataset_poscomp.loc[
    :,
    [
        "organização de arquivos e dados",
        "técnicas de programação",
        "circuitos digitais",
        "análise de algoritmos",
        "teoria dos grafos",
        "linguagens formais, autômatos e computabilidade",
        "algoritmos e estruturas de dados",
        "linguagens de programação",
        "sistemas operacionais",
        "arquitetura e organização de computadores",
    ],
].sum(axis=1)

# %%
dataset_poscomp["tec_computacao"] = dataset_poscomp.loc[
    :,
    [
        "redes de computadores",
        "computação gráfica",
        "inteligência artificial",
        "engenharia de software",
        "sistemas distribuídos",
        "compiladores",
        "processamento de imagens",
        "banco de dados",
    ],
].sum(axis=1)

# %%
dataset_poscomp["total"] = (
    dataset_poscomp["matematica"]
    + dataset_poscomp["fund_computacao"]
    + dataset_poscomp["tec_computacao"]
)

# %%
# será selecionados candidatos uma unica vez, ou seja não terá dados duplicados pelos candidatos.
dataset_unique_regis = dataset_poscomp.drop_duplicates(
    subset="cpf", keep="first", ignore_index=True
)

# %%
df_unique_regis = dataset_unique_regis[
    (dataset_unique_regis["cargo"] != "Autoavaliação")
]

# %%
unique_regis = dataset_unique_regis[
    (dataset_unique_regis["presente dia1"] != "N")
    & (dataset_unique_regis["cargo"] != "Autoavaliação")
]

# %%
sexo = df_unique_regis.groupby("presente dia1").size().reset_index()

# %%
sexo.loc["Total"] = sexo.sum()
sexo = sexo.T
sexo.rename(columns={1: "presentes"}, inplace=True)
sexo.drop("presente dia1", axis=0)

# Converter as colunas 'Total' e 'presentes' para o tipo numérico
colunas_numericas = ["Total", "presentes"]
sexo[colunas_numericas] = sexo[colunas_numericas].apply(pd.to_numeric, errors="coerce")
sexo["taxa_desistencia"] = ((sexo["Total"] - sexo["presentes"]) / sexo["Total"]) * 100
sexo.dropna(inplace=True)
sexo

# %%
np.round(sexo["taxa_desistencia"], decimals=2)

# %%
df_unique_regis["cargo"].value_counts()

# %%
teste_dados = unique_regis.loc[
    :,
    [
        "estado",
        "sexo",
        "regiao",
        "matematica",
        "fund_computacao",
        "tec_computacao",
        "total",
    ],
]

# %%
teste_dados = teste_dados[teste_dados["total"] >= 6]

# %%
def calcular_percentagem_acertos(dados, coluna_acertos):
    dados["%acerto_" + coluna_acertos] = (
        dados[coluna_acertos] / dados[coluna_acertos].sum()
    ) * 100


# Exemplo de uso:
# Supondo que 'teste_dados' é o seu DataFrame
calcular_percentagem_acertos(teste_dados, "matematica")
calcular_percentagem_acertos(teste_dados, "fund_computacao")
calcular_percentagem_acertos(teste_dados, "tec_computacao")
calcular_percentagem_acertos(teste_dados, "total")

# %%
# Bases de dados filtradas com a porcentagens de acertos por eixos de cada estado
percentil_eixos = (
    teste_dados.groupby("estado")
    .agg(
        {
            "%acerto_matematica": "sum",
            "%acerto_fund_computacao": "sum",
            "%acerto_tec_computacao": "sum",
            "%acerto_total": "sum",
        }
    )
    .reset_index()
)

# %%
# Bases de dados filtradas com a porcentagens de acertos por eixos de cada sexo
percentil_sexo = (
    teste_dados.groupby("sexo")
    .agg(
        {
            "%acerto_matematica": "sum",
            "%acerto_fund_computacao": "sum",
            "%acerto_tec_computacao": "sum",
            "%acerto_total": "sum",
        }
    )
    .reset_index()
)

# %%
# Bases de dados filtradas com a porcentagens de acertos por eixos de cada região
percentil_regiao = (
    teste_dados.groupby("regiao")
    .agg(
        {
            "%acerto_matematica": "sum",
            "%acerto_fund_computacao": "sum",
            "%acerto_tec_computacao": "sum",
            "%acerto_total": "sum",
        }
    )
    .reset_index()
)

# %%
percentil_eixos.columns

# %%
percentil_eixos = percentil_eixos.round(
    {"%acerto_matematica": 2, "%acerto_fund_computacao": 2, "%acerto_tec_computacao": 2}
)

# %%
percentil_eixos

# %% [markdown]
# ## Pré-processamento dos dados

# %%
df_poscomp = df.copy()

# %%
df_poscomp['cpf'].duplicated().sum()

# %%
df_poscomp.to_csv("../dados/poscomp_frame.csv", index=False)

# %%
df_poscomp.columns

# %%
100 / len(df_poscomp)

# %%
split = StratifiedShuffleSplit(test_size=0.010810810810810811)
for x, y in split.split(df_poscomp, df_poscomp["linhas_pesquisas"]):
    df_x = df_poscomp.iloc[x]
    df_y = df_poscomp.iloc[y]

# %%
df_x.shape, df_y.shape

# %%
df_y["linhas_pesquisas"].value_counts()

# %%
df_x["linhas_pesquisas"].value_counts()

# %%
def amostragem_estratificada(dataset, percentual):
    split = StratifiedShuffleSplit(test_size=percentual, random_state=1)
    for _, y in split.split(df_poscomp, df_poscomp["linhas_pesquisas"]):
        df_y = df_poscomp.iloc[y]
    return df_y

# %%
df_stratified = amostragem_estratificada(df_poscomp, 0.010810810810810811)
df_stratified.shape

# %% [markdown]
# ### Aprendizado de Máquina
