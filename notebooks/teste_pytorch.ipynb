# %%
# !pip install skorch
# Out:
# Requirement already satisfied: skorch in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.13.3 in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (from skorch) (1.26.3)
# Requirement already satisfied: scikit-learn>=0.22.0 in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (from skorch) (1.4.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (from skorch) (1.15.0)
# Requirement already satisfied: tabulate>=0.7.7 in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (from skorch) (0.9.0)
# Requirement already satisfied: tqdm>=4.14.0 in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (from skorch) (4.67.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (from scikit-learn>=0.22.0->skorch) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jeancarloscc/miniconda3/envs/poscomp/lib/python3.11/site-packages (from scikit-learn>=0.22.0->skorch) (3.5.0)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import torch
import torch.nn as nn
from skorch import NeuralNetClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
import torch.nn.functional as F
from torch import nn, optim

# %%
# %run ../services/imports.py
# %run ../services/visualization.py
from services.function import Function

# %%
df_poscomp = pd.read_csv("../dados/processed/dados_poscomp_completo_test.csv")

# %%
df_poscomp.head()
# Out:
#         idade       sexo estado presença               cargo  \
# 0  1989-11-29  masculino     ce        s  mestrado/doutorado
# 1  1995-02-23  masculino     rs        s  mestrado/doutorado
# 2  1991-12-13  masculino     sp        s  mestrado/doutorado
# 3  1986-09-29  masculino     pa        s  mestrado/doutorado
# 4  1997-12-26   feminino     am        s  mestrado/doutorado
#
#                            especialidade  matematica  fund_computacao  \
# 0                   teoria da computação        14.0             21.0
# 1  metodologias e técnicas de computação        16.0             22.0
# 2                 engenharia de software         4.0             16.0
# 3                 sistemas de informação         4.0             13.0
# 4                     computação gráfica         6.0             15.0
#
#    tec_computacao   ano         linhas_pesquisas area_concentration
# 0            10.0  2016   sistemas de informação        informatica
# 1            12.0  2016   engenharia de software        informatica
# 2             8.0  2016   engenharia de software        informatica
# 3             7.0  2016   sistemas de informação        informatica
# 4            11.0  2016  inteligência artificial         computacao

# %%
# converter os type das colunas
df_poscomp["ano"] = df_poscomp["ano"].astype("object")
# Primeiramente, será excluídos candidatos que realizaram o exame no Peru
df_poscomp = df_poscomp.query("estado != 'ou' & presença != 'n'")
df_poscomp["idade"] = df_poscomp.apply(Function.calculate_age, axis=1)
df_poscomp = df_poscomp.query('idade > 0')

# %%
df_poscomp
# Out:
#        idade       sexo estado presença               cargo  \
# 0         27  masculino     ce        s  mestrado/doutorado
# 1         21  masculino     rs        s  mestrado/doutorado
# 2         25  masculino     sp        s  mestrado/doutorado
# 3         30  masculino     pa        s  mestrado/doutorado
# 4         19   feminino     am        s  mestrado/doutorado
# ...      ...        ...    ...      ...                 ...
# 13470     22   feminino     mg        s  mestrado/doutorado
# 13471     48  masculino     pb        s  mestrado/doutorado
# 13472     24  masculino     sp        s  mestrado/doutorado
# 13473     25  masculino     es        s  mestrado/doutorado
# 13474     24  masculino     rs        s  mestrado/doutorado
#
#                                especialidade  matematica  fund_computacao  \
# 0                       teoria da computação        14.0             21.0
# 1      metodologias e técnicas de computação        16.0             22.0
# 2                     engenharia de software         4.0             16.0
# 3                     sistemas de informação         4.0             13.0
# 4                         computação gráfica         6.0             15.0
# ...                                      ...         ...              ...
# 13470                inteligência artificial        14.0             16.0
# 13471                  redes de computadores        10.0             16.0
# 13472                 engenharia de software         9.0             18.0
# 13473                inteligência artificial        10.0             16.0
# 13474                    sistemas embarcados        13.0             17.0
#
#        tec_computacao   ano         linhas_pesquisas area_concentration
# 0                10.0  2016   sistemas de informação        informatica
# 1                12.0  2016   engenharia de software        informatica
# 2                 8.0  2016   engenharia de software        informatica
# 3                 7.0  2016   sistemas de informação        informatica
# 4                11.0  2016  inteligência artificial         computacao
# ...               ...   ...                      ...                ...
# 13470             8.0  2019  inteligência artificial         computacao
# 13471             9.0  2019    redes de computadores        informatica
# 13472             8.0  2019   engenharia de software        informatica
# 13473             6.0  2019  inteligência artificial         computacao
# 13474             5.0  2019    redes de computadores        informatica
#
# [10976 rows x 12 columns]

# %%
X_dataset = df_poscomp.drop(columns=['ano', 'especialidade'])

# %%
X_dataset['linhas_pesquisas'].value_counts()
# Out:
# linhas_pesquisas
# inteligência artificial    3663
# sistemas de computação     2472
# engenharia de software     2463
# redes de computadores      1228
# sistemas de informação     1150
# Name: count, dtype: int64

# %%
def encode_categorical_columns(df, columns):
    le = LabelEncoder()
    for col in columns:
        df[col] = le.fit_transform(df[col])
    return df

categorical_columns = ['linhas_pesquisas', 'sexo', ]
X_dataset = encode_categorical_columns(X_dataset, categorical_columns)

# %%
X = X_dataset.drop(['linhas_pesquisas'], axis=1).values
y = X_dataset['linhas_pesquisas'].values

# %%
X
# Out:
# array([[14., 21., 10.],
#        [16., 22., 12.],
#        [ 4., 16.,  8.],
#        ...,
#        [ 9., 18.,  8.],
#        [10., 16.,  6.],
#        [13., 17.,  5.]])

# %%
X.shape
# Out:
# (10976, 3)

# %%
y.shape
# Out:
# (10976,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
np.unique(y_train)
# Out:
# array([0, 1, 2, 3, 4])

# %%
X_train = torch.tensor(X_train, dtype = torch.float)
y_train = torch.tensor(y_train, dtype = torch.long)

# %%
class classificador_torch(nn.Module):
    def __init__(self, activation, neurons, initializer):
        super().__init__()
        
        self.dense0 = nn.Linear(3, neurons)
        initializer(self.dense0.weight)
        self.activation0 = activation
        
        self.dense1 = nn.Linear(neurons, neurons)
        initializer(self.dense1.weight)
        self.activation1 = activation

        self.dense2 = nn.Linear(neurons, neurons)  # Nova camada oculta
        initializer(self.dense2.weight)
        self.activation2 = activation

        self.dense3 = nn.Linear(neurons, neurons)  # Outra nova camada
        initializer(self.dense3.weight)
        self.activation3 = activation
        
        self.dense4 = nn.Linear(neurons, 5)  # Camada de saída (3 classes)
        
        # self.dropout = nn.Dropout(dropout)
        
        self.output = nn.Softmax()

    def forward(self, X):
        X = self.dense0(X)
        X = self.activation0(X)
        # X = self.dropout(X)

        X = self.dense1(X)
        X = self.activation1(X)
        # X = self.dropout(X)

        X = self.dense2(X)
        X = self.activation2(X)
        # X = self.dropout(X)

        X = self.dense3(X)
        X = self.activation3(X)
        # X = self.dropout(X)

        X = self.dense4(X)  # Saída final sem ativação (CrossEntropyLoss espera logits)
        X = self.output(X)
        return X

# %%
# Hiperparâmetros do modelo
activation = F.relu
initializer = nn.init.uniform_
neurons = 50
# dropout_rate = 0.2

# Criando o classificador skorch
classificador_sklearn = NeuralNetClassifier(
    module=classificador_torch,  # Passa a classe, não uma instância
    module__activation=activation,
    module__neurons=neurons,
    module__initializer=initializer,
    # module__dropout=dropout_rate,
    criterion=torch.nn.CrossEntropyLoss,
    train_split=False,
    optimizer=optim.Adam,
    optimizer__weight_decay=0.0001,
    max_epochs=100,  # Número de épocas
    batch_size=32
)

print(classificador_sklearn)
# Out:
# <class 'skorch.classifier.NeuralNetClassifier'>[uninitialized](
#   module=<class '__main__.classificador_torch'>,
#   module__activation=<function relu at 0x78158dbcad40>,
#   module__initializer=<function uniform_ at 0x781580b69800>,
#   module__neurons=50,
# )

# %%
resultados = cross_val_score(classificador_sklearn, X_train, y_train, cv = 5,
                             scoring='accuracy')
# Out:
#   epoch    train_loss     dur
# -------  ------------  ------
#       1        1.6767  0.2783
#       2        1.5521  0.2027
#       3        1.5486  0.2028
#       4        1.5474  0.2024
#       5        1.5470  0.2038
#       6        1.5468  0.2053
#       7        1.5469  0.2153
#       8        1.5467  0.2339
#       9        1.5468  0.2623
#      10        1.5466  0.2617
#      11        1.5468  0.2640
#      12        1.5468  0.2636
#      13        1.5468  0.2532
#      14        1.5466  0.2606
#      15        1.5469  0.2632
#      16        1.5467  0.2622
#      17        1.5468  0.2523
#      18        1.5468  0.2542
#      19        1.5468  0.2587
#      20        1.5468  0.2592
#      21        1.5468  0.2649
#      22        1.5467  0.2629
#      23        1.5468  0.2584
#      24        1.5467  0.2641
#      25        1.5468  0.2739
#      26        1.5467  0.2729
#      27        1.5468  0.2847
#      28        1.5470  0.3005
#      29        1.5467  0.2923
#      30        1.5467  0.2836
#      31        1.5467  0.2753
#      32        1.5469  0.2607
#      33        1.5467  0.2539
#      34        1.5468  0.2565
#      35        1.5467  0.2585
#      36        1.5467  0.2703
#      37        1.5467  0.2846
#      38        1.5467  0.2936
#      39        1.5467  0.2862
#      40        1.5467  0.2821
#      41        1.5467  0.2801
#      42        1.5467  0.2918
#      43        1.5468  0.2847
#      44        1.5466  0.2622
#      45        1.5468  0.3225
#      46        1.5467  0.2689
#      47        1.5468  0.2697
#      48        1.5467  0.2596
#      49        1.5466  0.2572
#      50        1.5468  0.2624
#      51        1.5467  0.2556
#      52        1.5467  0.2595
#      53        1.5467  0.2750
#      54        1.5467  0.2631
#      55        1.5468  0.2667
#      56        1.5468  0.2709
#      57        1.5467  0.2767
#      58        1.5468  0.2761
#      59        1.5467  0.2797
#      60        1.5467  0.2835
#      61        1.5467  0.2866
#      62        1.5467  0.2840
#      63        1.5468  0.2834
#      64        1.5469  0.2738
#      65        1.5471  0.2646
#      66        1.5468  0.2592
#      67        1.5470  0.2509
#      68        1.5468  0.2802
#      69        1.5469  0.2540
#      70        1.5464  0.2553
#      71        1.5468  0.2538
#      72        1.5467  0.2537
#      73        1.5467  0.2553
#      74        1.5467  0.2713
#      75        1.5467  0.2595
#      76        1.5467  0.2634
#      77        1.5467  0.2641
#      78        1.5467  0.2679
#      79        1.5467  0.2723
#      80        1.5467  0.2741
#   epoch    train_loss     dur
# -------  ------------  ------
#       1        1.6567  0.2068
#       2        1.5734  0.2035
#       3        1.5735  0.2028
#       4        1.5632  0.2068
#       5        1.5730  0.2039
#       6        1.5734  0.2024
#       7        1.5514  0.2035
#       8        1.5500  0.2142
#       9        1.5478  0.2830
#      10        1.5481  0.2445
#      11        1.5469  0.2354
#      12        1.5473  0.2356
#      13        1.5495  0.2409
#      14        1.5448  0.2401
#      15        1.5455  0.2429
#      16        1.5472  0.2445
#      17        1.5543  0.2404
#      18        1.5509  0.2396
#      19        1.5474  0.2451
#      20        1.5473  0.2488
#      21        1.5472  0.2508
#      22        1.5472  0.2532
#      23        1.5472  0.2527
#      24        1.5472  0.2536
#      25        1.5457  0.2591
#      26        1.5510  0.2534
#      27        1.5474  0.2448
#      28        1.5458  0.2608
#      29        1.5488  0.2469
#      30        1.5457  0.2531
#      31        1.5485  0.2461
#      32        1.5495  0.2452
#      33        1.5472  0.2512
#      34        1.5475  0.2482
#      35        1.5472  0.2508
#      36        1.5471  0.2537
#      37        1.5471  0.2565
#      38        1.5471  0.2585
#      39        1.5471  0.2628
#      40        1.5471  0.2658
#      41        1.5471  0.2678
#      42        1.5471  0.2678
#      43        1.5472  0.2662
#      44        1.5469  0.2662
#      45        1.5435  0.2565
#      46        1.5439  0.2528
#      47        1.5592  0.2551
#      48        1.5472  0.2538
#      49        1.5478  0.2564
#      50        1.5439  0.2580
#      51        1.5450  0.2603
#      52        1.5494  0.2607
#      53        1.5485  0.2585
#      54        1.5472  0.2613
#      55        1.5482  0.2572
#      56        1.5477  0.2624
#      57        1.5489  0.3156
#      58        1.5453  0.2540
#      59        1.5729  0.2626
#      60        1.5696  0.2703
#      61        1.5526  0.2557
#      62        1.5469  0.2562
#      63        1.5470  0.2507
#      64        1.5615  0.2604
#      65        1.5424  0.2589
#      66        1.5470  0.2593
#      67        1.5479  0.2595
#      68        1.5462  0.2653
#      69        1.5473  0.2611
#      70        1.5562  0.2615
#      71        1.5439  0.2505
#      72        1.5481  0.2478
#      73        1.5486  0.2503
#      74        1.5460  0.2524
#      75        1.5443  0.2547
#      76        1.5495  0.2564
#      77        1.5728  0.2577
#      78        1.5733  0.2607
#      79        1.5733  0.2674
#      80        1.5733  0.2667
#      81        1.5694  0.2578
#      82        1.5484  0.3355
#      83        1.5473  0.2486
#      84        1.5475  0.2441
#      85        1.5475  0.2462
#      86        1.5471  0.2464
#      87        1.5473  0.2440
#      88        1.5477  0.2493
#      89        1.5472  0.2480
#      90        1.5470  0.2467
#      91        1.5470  0.2451
#      92        1.5471  0.2506
#      93        1.5470  0.2498
#      94        1.5470  0.2535
#      95        1.5469  0.2551
#      96        1.5471  0.2564
#      97        1.5470  0.2618
#      98        1.5470  0.2619
#      99        1.5470  0.2654
#     100        1.5468  0.2560

# %%
resultados
# Out:
# array([0.33116461, 0.33181522, 0.33116461, 0.33138021, 0.33138021])
