# %% [markdown]
# # Organização dos dados

# %% [markdown]
# <p>Neste notebook serão organizados os dados dos participantes que realizaram o POSCOMP dos anos de 2016 a 2022. Os participantes dos anos de 2023 não entram porque a SBC determinou que não serão contatos os temas aplicados nas provas, apenas os eixos centrais, os quais são: Matemática, Fundamentos da Computação e Tecnologia da Computação.</p>

# %% [markdown]
# #### Importação das bibliotecas

# %%
# %run ../services/imports.py
# %run ../services/visualization.py

# %%
dataframe2016_2019 = pd.read_csv("../dados/processed/2016-2019/dataset_poscomp.csv")

# %%
dataframe2022 = pd.read_csv("../dados/processed/2016-2019/dataset_poscomp2022.csv")

# %%
dataframe2016_2019.drop(columns=['cpf','nome','inscricao'], inplace=True)

# %%
list_order_columns = ['idade','sexo','estado','presença','cargo','especialidade','algoritmos_e_estruturas_de_dados',
 'análise_combinatória',
 'análise_de_algoritmos',
 'arquitetura_e_organização_de_computadores',
 'banco_de_dados',
 'cálculo_diferencial_e_integral',
 'circuitos_digitais',
 'compiladores',
 'computação_gráfica',
 'engenharia_de_software',
 'geometria_analítica',
 'inteligência_artificial',
 'linguagens_de_programação',
 'linguagens_formais_autômatos_e_computabilidade',
 'lógica_matemática',
 'matemática_discreta',
 'organização_de_arquivos_e_dados',
 'probabilidade_e_estatística',
 'processamento_de_imagens',
 'redes_de_computadores',
 'sistemas_distribuídos',
 'sistemas_operacionais',
 'teoria_dos_grafos',
 'técnicas_de_programação',
 'álgebra_linear', 'ano']

# %%
dataframe2016_2019.columns
# Out:
# Index(['idade', 'sexo', 'estado', 'especialidade', 'presença', 'cargo',
#        'matemática_discreta', 'cálculo_diferencial_e_integral',
#        'álgebra_linear', 'geometria_analítica', 'análise_combinatória',
#        'probabilidade_e_estatística', 'lógica_matemática',
#        'organização_de_arquivos_e_dados', 'técnicas_de_programação',
#        'circuitos_digitais', 'análise_de_algoritmos', 'teoria_dos_grafos',
#        'linguagens_formais_autômatos_e_computabilidade',
#        'algoritmos_e_estruturas_de_dados', 'linguagens_de_programação',
#        'sistemas_operacionais', 'arquitetura_e_organização_de_computadores',
#        'redes_de_computadores', 'computação_gráfica',
#        'inteligência_artificial', 'engenharia_de_software',
#        'sistemas_distribuídos', 'compiladores', 'processamento_de_imagens',
#        'banco_de_dados', 'ano'],
#       dtype='object')

# %%
dataframe2016_2019 = dataframe2016_2019.reindex(list_order_columns, axis=1)

# %%
dataframe2016_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14573 entries, 0 to 14572
# Data columns (total 32 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   idade                                           14573 non-null  object
#  1   sexo                                            14573 non-null  object
#  2   estado                                          14573 non-null  object
#  3   presença                                        14573 non-null  object
#  4   cargo                                           14573 non-null  object
#  5   especialidade                                   13699 non-null  object
#  6   algoritmos_e_estruturas_de_dados                11827 non-null  float64
#  7   análise_combinatória                            11827 non-null  float64
#  8   análise_de_algoritmos                           11827 non-null  float64
# ...

# %%
list(dataframe2022.columns)
# Out:
# ['idade',
#  'sexo',
#  'estado',
#  'presença',
#  'cargo',
#  'especialidade',
#  'algoritmos_e_estrutura_de_dados',
#  'análise_combinatória',
#  'análise_de_algoritmos',
#  'arquitetura_e_organização_de_computadores',
#  'banco_de_dados',
#  'calculo_diferencial_e_integral',
#  'circuitos_digitais',
#  'compiladores',
#  'computação_gráfica',
#  'engenharia_de_software',
#  'geometria_analítica',
#  'inteligência_artificial',
#  'linguagens_de_programação',
#  'linguagens_formais_autômatos_e_computabilidade',
#  'lógica_matemática',
#  'matemática_discreta',
#  'organização_de_arquivos_e_dados',
#  'probabilidade_e_estatística',
#  'processamento_de_imagens',
#  'redes_de_computadores',
#  'sistemas_distribuídos',
#  'sistemas_operacionais',
#  'teoria_dos_grafos',
#  'técnicas_de_programação',
#  'álgebra_linear',
#  'ANO']

# %%
rename_columns = {
    'algoritmos_e_estrutura_de_dados': 'algoritmos_e_estruturas_de_dados',
    'álgebra_linear': 'algebra_linear',
    'análise_combinatória': 'analise_combinatoria',
    'análise_de_algoritmos': 'analise_de_algoritmos',
    'arquitetura_e_organização_de_computadores': 'arquitetura_e_organizacao_de_computadores',
    'banco_de_dados': 'banco_de_dados',
    'cálculo_diferencial_e_integral': 'calculo_diferencial_e_integral',
    'circuitos_digitais': 'circuitos_digitais',
    'compiladores': 'compiladores',
    'computação_gráfica': 'computacao_grafica',
    'engenharia_de_software': 'engenharia_de_software',
    'geometria_analítica': 'geometria_analitica',
    'inteligência_artificial': 'inteligencia_artificial',
    'linguagens_de_programação': 'linguagens_de_programacao',
    'linguagens_formais_autômatos_e_computabilidade': 'linguagens_formais_automatos_e_computabilidade',
    'lógica_matemática': 'logica_matematica',
    'matemática_discreta': 'matematica_discreta',
    'organização_de_arquivos_e_dados': 'organizacao_de_arquivos_e_dados',
    'probabilidade_e_estatística': 'probabilidade_e_estatistica',
    'processamento_de_imagens': 'processamento_de_imagens',
    'redes_de_computadores': 'redes_de_computadores',
    'sistemas_distribuídos': 'sistemas_distribuidos',
    'sistemas_operacionais': 'sistemas_operacionais',
    'técnicas_de_programação': 'tecnicas_de_programacao',
    'teoria_dos_grafos': 'teoria_dos_grafos',
    'ANO': 'ano'
}

# %%
rename_columns2 = {
    'algoritmos_e_estrutura_de_dados': 'algoritmos_e_estrutura_de_dados',
    'álgebra_linear': 'algebra_linear',
    'análise_combinatória': 'analise_combinatoria',
    'análise_de_algoritmos': 'analise_de_algoritmos',
    'arquitetura_e_organização_de_computadores': 'arquitetura_e_organizacao_de_computadores',
    'banco_de_dados': 'banco_de_dados',
    'cálculo_diferencial_e_integral': 'calculo_diferencial_e_integral',
    'circuitos_digitais': 'circuitos_digitais',
    'compiladores': 'compiladores',
    'computação_gráfica': 'computacao_grafica',
    'engenharia_de_software': 'engenharia_de_software',
    'geometria_analítica': 'geometria_analitica',
    'inteligência_artificial': 'inteligencia_artificial',
    'linguagens_de_programação': 'linguagens_de_programacao',
    'linguagens_formais_autômatos_e_computabilidade': 'linguagens_formais_automatos_e_computabilidade',
    'lógica_matemática': 'logica_matematica',
    'matemática_discreta': 'matematica_discreta',
    'organização_de_arquivos_e_dados': 'organizacao_de_arquivos_e_dados',
    'probabilidade_e_estatística': 'probabilidade_e_estatistica',
    'processamento_de_imagens': 'processamento_de_imagens',
    'redes_de_computadores': 'redes_de_computadores',
    'sistemas_distribuídos': 'sistemas_distribuidos',
    'sistemas_operacionais': 'sistemas_operacionais',
    'técnicas_de_programação': 'tecnicas_de_programacao',
    'teoria_dos_grafos': 'teoria_dos_grafos',
    'ANO': 'ano'
}

# %%
dataframe2022.rename(columns=rename_columns, inplace=True)

# %%
dataframe2016_2019.head()
# Out:
#         idade sexo estado presença               cargo  \
# 0  1992-10-27    m     ou        s  mestrado/doutorado
# 1  1989-11-29    m     ce        s  mestrado/doutorado
# 2  1995-02-23    m     rs        s  mestrado/doutorado
# 3  1991-12-13    m     sp        s  mestrado/doutorado
# 4  1986-09-29    m     pa        s  mestrado/doutorado
#
#                                     especialidade  \
# 0                         inteligência artificial
# 1                            teoria da computação
# 2            metodologia e técnicas da computação
# 3                          engenharia de software
# 4  modelagem e gerência de sistemas de informação
#
#    algoritmos_e_estruturas_de_dados  análise_combinatória  \
# 0                               3.0                   2.0
# 1                               1.0                   1.0
# 2                               3.0                   2.0
# 3                               1.0                   0.0
# ...

# %%
dataframe2016_2019.rename(columns=rename_columns, inplace=True)

# %%
dataframe2022.columns
# Out:
# Index(['idade', 'sexo', 'estado', 'presença', 'cargo', 'especialidade',
#        'algoritmos_e_estruturas_de_dados', 'analise_combinatoria',
#        'analise_de_algoritmos', 'arquitetura_e_organizacao_de_computadores',
#        'banco_de_dados', 'calculo_diferencial_e_integral',
#        'circuitos_digitais', 'compiladores', 'computacao_grafica',
#        'engenharia_de_software', 'geometria_analitica',
#        'inteligencia_artificial', 'linguagens_de_programacao',
#        'linguagens_formais_automatos_e_computabilidade', 'logica_matematica',
#        'matematica_discreta', 'organizacao_de_arquivos_e_dados',
#        'probabilidade_e_estatistica', 'processamento_de_imagens',
#        'redes_de_computadores', 'sistemas_distribuidos',
#        'sistemas_operacionais', 'teoria_dos_grafos', 'tecnicas_de_programacao',
#        'algebra_linear', 'ano'],
#       dtype='object')

# %% [markdown]
# #### Concatenação

# %%
dataframe_completo = pd.concat([dataframe2016_2019, dataframe2022])

# %%
dataframe_completo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15109 entries, 0 to 535
# Data columns (total 32 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   idade                                           15109 non-null  object
#  1   sexo                                            15109 non-null  object
#  2   estado                                          15109 non-null  object
#  3   presença                                        15109 non-null  object
#  4   cargo                                           15109 non-null  object
#  5   especialidade                                   14228 non-null  object
#  6   algoritmos_e_estruturas_de_dados                12227 non-null  float64
#  7   analise_combinatoria                            12227 non-null  float64
#  8   analise_de_algoritmos                           12227 non-null  float64
# ...

# %%
dataframe_completo['sexo'].replace({'m':'masculino', 'f':'feminino'}, inplace=True)

# %%
dataframe_completo.to_csv('../dados/processed/df_poscomp2016-2022.csv', index=False)

# %% [markdown]
# ### Organizar o dataframe dos participantes de 2023

# %% [markdown]
# <p> Nesta parte serão trabalhados com os dados do POSCOMP 2023. Nestes dados não estão presentes todos os temas das disciplinas, apenas o eixos de Matemática, Fundamentos da Computação e Tecnologia da Computação. </p>

# %%
dataframe_2023 = pd.read_csv('../dados/processed/2016-2019/dataset_poscomp2023.csv')

# %%
dataframe_2023.rename(columns={'matemática':'matematica'}, inplace=True)

# %%
dataframe_2023
# Out:
#           idade       sexo estado presença               cargo  \
# 0    1998-05-13  masculino     pr        s  mestrado/doutorado
# 1    1984-07-29  masculino     ba        s  mestrado/doutorado
# 2    1993-02-03  masculino     mg        s  mestrado/doutorado
# 3    1998-02-13  masculino     sp        s  mestrado/doutorado
# 4    1992-11-16  masculino     rj        n  mestrado/doutorado
# ..          ...        ...    ...      ...                 ...
# 756  1996-10-31  masculino     sp        n  mestrado/doutorado
# 757  1998-08-06  masculino     mg        s  mestrado/doutorado
# 758  1997-10-17  masculino     sp        s  mestrado/doutorado
# 759  1995-03-20  masculino     rs        s  mestrado/doutorado
# 760  1995-06-07   feminino     ou        s  mestrado/doutorado
#
#                                          especialidade  matematica  \
# 0                           inteligencia computacional        14.0
# 1                        redes e sistemas distribuidos        15.0
# ...

# %%
dataframe_2023.to_csv('../dados/processed/df_poscomp2023.csv', index=False)

# %% [markdown]
# ## Remover os temas da prova

# %%
dataframe_completo.shape
# Out:
# (15109, 32)

# %%
dataframe_completo.query("especialidade == 'aprendizagem de ma?quina e minerac?a?o'")
# Out:
#             idade       sexo estado presença               cargo  \
# 9534   1994-11-17  masculino     al        s  mestrado/doutorado
# 9699   1993-08-29  masculino     se        s  mestrado/doutorado
# 10579  1996-04-24  masculino     ba        s  mestrado/doutorado
# 10874  1997-09-04   feminino     ce        s  mestrado/doutorado
#
#                                 especialidade  \
# 9534   aprendizagem de ma?quina e minerac?a?o
# 9699   aprendizagem de ma?quina e minerac?a?o
# 10579  aprendizagem de ma?quina e minerac?a?o
# 10874  aprendizagem de ma?quina e minerac?a?o
#
#        algoritmos_e_estruturas_de_dados  analise_combinatoria  \
# 9534                                0.0                   1.0
# 9699                                0.0                   2.0
# 10579                               0.0                   1.0
# 10874                               0.0                   3.0
#
#        analise_de_algoritmos  arquitetura_e_organizacao_de_computadores  ...  \
# ...
