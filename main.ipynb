# %%
# %run services/imports.py
# Out:
# importing Jupyter notebook from C:\Users\jeanc\projetos pessoais\project_dataScience_POSCOMP\services\especialidades.ipynb

# %%
df = pd.read_csv('dados/nota_poscomp2023.csv', sep=';')

# %%
df
# Out:
#                             Column1        Column2     Column3  \
# 0                              Nome      Inscrição  Matemática
# 1     Abner Fontebom Bissolli Costa  76101704327-1       14,00
# 2             Adiel Ramos de Cristo  76101676578-3       15,00
# 3    Adnilson Brás da Silva Santana  76101704007-3       20,00
# 4     Adriano Augusto Antongiovanni  76101688256-3       14,00
# ..                              ...            ...         ...
# 722            William Silva Mendes  76101694039-2           -
# 723      Yuri Dimitre Dias de Faria  76101683999-5       14,00
# 724             Yuri Nicolau Freire  76101680014-5       13,00
# 725                  Yuri Silva Vaz  76101686704-6       11,00
# 726          Yuvisa Quispe Palomino  76101687365-2       13,00
#
#                        Column4                     Column5        Column6
# 0    Fundamentos da Computação  Tecnologia de Computadores  Total da Nota
# ...
